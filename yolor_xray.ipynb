# %% [markdown]
# <a href="https://colab.research.google.com/github/cksdlakstp12/AirforceStartUPContest/blob/main/yolor_xray.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 데이터 정제 및 준비

# %% [markdown]
# ## Directory maker

# %%
# /content/drive/MyDrive/datasets/xray/Train/company/object/category/img
# /content/drive/MyDrive/datasets/xray/Annotation/Train/company/object/category/img
# /content/drive/MyDrive/datasets/xray/Validation/company/object/category/img
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/company/object/category/img

# %%
import os, shutil

modes = ["Train", "Validation"]
companies = ["Smith", "Astrophysics", "Rapiscan"]
objects = ["Aerosol", "Alcohol", "Awl", "Axe", "Bat", "Battery", "Bullet", "Chisel", "ElectronicCigarettes",
              "ElectronicCigarettesLiquid", "Firecracker", "Gun", "GunParts", "Hammer", "HandCuffs",
              "HDDExternal", "HDD", "Knife", "LapTop", "Lighter", "Liquid", "Match", "MetalPipe", "NailClippers",
              "Plier", "PortableGas", "Saw", "Scissors", "Screwdriver", "SmartPhone", "SolidFuel", "Spanner",
              "SSD", "SupplymentaryBattery", "TabletPC", "Thinner", "ThrowingKnife", "USB", "ZippoOil"]
categories = ["Multiple_Categories", "Multiple_Other", "Single_Default", "Single_Other"]

ROOT = f"/content/drive/MyDrive/datasets/xray/Annotation"
for mode in modes:
  for company in companies:
    for obj in objects:
      path1 = f"{ROOT}/{mode}/{company}/{obj}"
      if not os.path.exists(path1):
        os.mkdir(path1)
      for ctg in categories:
        path2 = f"{path1}/{ctg}"
        if not os.path.exists(path2):
          os.mkdir(path2)

# %% [markdown]
# ## 데이터 압축 해제

# %% [markdown]
# ### Validation

# %%
import os
import zipfile
import glob

KW = "Rapiscan"
idx = 3

ROOT = f"/content/drive/MyDrive/datasets/xray/Validation/{KW}"
zip_path = f"{ROOT}/{KW}_{idx}.zip"
print(zip_path, "extracting")
unpack_zipfile = zipfile.ZipFile(zip_path)
unpack_zipfile.extractall(ROOT)
unpack_zipfile.close()
os.remove(zip_path)
print(zip_path, "extracted!")
# Out:
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Rapiscan_3.zip extracting
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Rapiscan_3.zip extracted!

# %% [markdown]
# ### Train : local work

# %%
import os
import zipfile
import glob

file_name = "[Smith]Bullet.zip"
path = f"/content/drive/MyDrive/datasets/xray/Train/Smith/{file_name}"
os.system(f"cp {path} /content")

KW = "Smith"
ROOT = f"/content/drive/MyDrive/datasets/xray/Train/{KW}"

zipfile_name = f"/content/{file_name}"

print(zipfile_name, "extracting")
unpack_zipfile = zipfile.ZipFile(zipfile_name)
unpack_zipfile.extractall(ROOT)
unpack_zipfile.close()

# os.remove(zipfile_name)

print(zipfile_name, "extracted!")
# Out:
# /content/[Rapiscan]Lighter.zip extracting
# /content/[Rapiscan]Lighter.zip extracted!

# %% [markdown]
# ### Train : drive work

# %%
import os
import zipfile
import glob
import os

KW = "Rapiscan"
ROOT = f"/content/drive/MyDrive/datasets/xray/Train/{KW}"
GLOB_PATH = f"{ROOT}/*.zip"

zipfile_name_list = glob.glob(GLOB_PATH)[:1]

for zipfile_name in zipfile_name_list:
  print(zipfile_name, "extracting")
  unpack_zipfile = zipfile.ZipFile(zipfile_name)
  unpack_zipfile.extractall(ROOT)
  unpack_zipfile.close()

  # os.remove(zipfile_name)

  print(zipfile_name, "extracted!")
# Out:
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/[Rapiscan]Knife.zip extracting
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/[Rapiscan]Knife.zip extracted!

# %% [markdown]
# ## checker

# %% [markdown]
# ### 어떤 디렉토리가 존재하지 않는지 확인

# %%
import os
import glob

modes = [
  "Train", 
  "Validation"
]
companies = [
  "Smith",
  "Astrophysics",
  "Rapiscan"
]
classes = [
  "Aerosol", "Alcohol", "Awl", "Axe", "Bat", "Battery", "Bullet", "Chisel", "ElectronicCigarettes",
  "ElectronicCigarettesLiquid", "Firecracker", "Gun", "GunParts", "Hammer", "HandCuffs",
  "HDDExternal", "HDD", "Knife", "LapTop", "Lighter", "Liquid", "Match", "MetalPipe", "NailClippers",
  "Plier", "PortableGas", "Saw", "Scissors", "Screwdriver", "SmartPhone", "SolidFuel", "Spanner",
  "SSD", "SupplymentaryBattery", "TabletPC", "Thinner", "ThrowingKnife", "USB", "ZippoOil"
]
categories = [
  "Multiple_Categories",
  "Multiple_Other",
  "Single_Default",
  "Single_Other"
]

for m in modes:
  for com in companies:
    for cls in classes:
      for ctg in categories:
        path = f"/content/drive/MyDrive/datasets/xray/{m}/{com}/{cls}/{ctg}"
        if not os.path.exists(path):
          print(path, "is not exist...")
# Out:
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/LapTop/Multiple_Other is not exist...
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/TabletPC/Multiple_Other is not exist...

# %% [markdown]
# ### png파일이 존재하는지 확인

# %%
import os
import glob

modes = [
  "Train", 
  "Validation"
]
companies = [
  "Smith",
  "Astrophysics",
  "Rapiscan"
]
classes = [
  "Aerosol", "Alcohol", "Awl", "Axe", "Bat", "Battery", "Bullet", "Chisel", "ElectronicCigarettes",
  "ElectronicCigarettesLiquid", "Firecracker", "Gun", "GunParts", "Hammer", "HandCuffs",
  "HDDExternal", "HDD", "Knife", "LapTop", "Lighter", "Liquid", "Match", "MetalPipe", "NailClippers",
  "Plier", "PortableGas", "Saw", "Scissors", "Screwdriver", "SmartPhone", "SolidFuel", "Spanner",
  "SSD", "SupplymentaryBattery", "TabletPC", "Thinner", "ThrowingKnife", "USB", "ZippoOil"
]
categories = [
  "Multiple_Categories",
  "Multiple_Other",
  "Single_Default",
  "Single_Other"
]

for m in modes:
  for com in companies:
    for cls in classes:
      for ctg in categories:
        path = f"/content/drive/MyDrive/datasets/xray/{m}/{com}/{cls}/{ctg}"
        if os.path.exists(path):
          png_list_len = len(glob.glob(f"{path}/*.png"))
          is_exists = "file exists" if png_list_len != 0 else "XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX"
          print(f"{path} : {is_exists}")

          if png_list_len == 0:
            txt_file_path = "/content/drive/MyDrive/datasets/xray/none_file_dirs.txt"
            with open(txt_file_path, "a") as f:
              f.write(path + "\n")
        else:
          print(path, "XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
      print("=="*50)
    print("=="*50)
# Out:
# /content/drive/MyDrive/datasets/xray/Train/Smith/Aerosol/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Aerosol/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Aerosol/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Aerosol/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Alcohol/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Alcohol/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Alcohol/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Alcohol/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Awl/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Awl/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Awl/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Awl/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Axe/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Axe/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Axe/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Axe/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Bat/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Bat/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Bat/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Bat/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Battery/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Battery/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Battery/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Battery/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Bullet/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Bullet/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Bullet/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Bullet/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Chisel/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Chisel/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Chisel/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Chisel/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/ElectronicCigarettes/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/ElectronicCigarettes/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/ElectronicCigarettes/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/ElectronicCigarettes/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/ElectronicCigarettesLiquid/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/ElectronicCigarettesLiquid/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/ElectronicCigarettesLiquid/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/ElectronicCigarettesLiquid/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Firecracker/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Firecracker/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Firecracker/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Firecracker/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Gun/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Gun/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Gun/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Gun/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/GunParts/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/GunParts/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/GunParts/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/GunParts/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Hammer/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Hammer/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Hammer/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Hammer/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/HandCuffs/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/HandCuffs/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/HandCuffs/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/HandCuffs/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/HDDExternal/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/HDDExternal/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/HDDExternal/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/HDDExternal/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/HDD/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/HDD/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/HDD/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/HDD/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Knife/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Knife/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Knife/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Knife/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/LapTop/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/LapTop/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/LapTop/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/LapTop/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Lighter/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Lighter/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Lighter/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Lighter/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Liquid/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Liquid/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Liquid/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Liquid/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Match/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Match/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Match/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Match/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/MetalPipe/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/MetalPipe/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/MetalPipe/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/MetalPipe/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/NailClippers/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/NailClippers/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/NailClippers/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/NailClippers/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Plier/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Plier/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Plier/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Plier/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/PortableGas/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/PortableGas/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/PortableGas/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/PortableGas/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Saw/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Saw/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Saw/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Saw/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Scissors/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Scissors/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Scissors/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Scissors/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Screwdriver/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Screwdriver/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Screwdriver/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Screwdriver/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/SmartPhone/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/SmartPhone/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/SmartPhone/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/SmartPhone/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/SolidFuel/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/SolidFuel/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/SolidFuel/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/SolidFuel/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Spanner/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Spanner/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Spanner/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Spanner/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/SSD/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/SSD/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/SSD/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/SSD/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/SupplymentaryBattery/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/SupplymentaryBattery/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/SupplymentaryBattery/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/SupplymentaryBattery/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/TabletPC/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/TabletPC/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/TabletPC/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/TabletPC/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Thinner/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Thinner/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Thinner/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/Thinner/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/ThrowingKnife/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/ThrowingKnife/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/ThrowingKnife/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/ThrowingKnife/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/USB/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/USB/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/USB/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/USB/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/ZippoOil/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/ZippoOil/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/ZippoOil/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Smith/ZippoOil/Single_Other : file exists
# ====================================================================================================
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Aerosol/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Aerosol/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Aerosol/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Aerosol/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Alcohol/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Alcohol/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Alcohol/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Alcohol/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Awl/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Awl/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Awl/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Awl/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Axe/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Axe/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Axe/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Axe/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Bat/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Bat/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Bat/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Bat/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Battery/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Battery/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Battery/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Battery/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Bullet/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Bullet/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Bullet/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Bullet/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Chisel/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Chisel/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Chisel/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Chisel/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ElectronicCigarettes/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ElectronicCigarettes/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ElectronicCigarettes/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ElectronicCigarettes/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ElectronicCigarettesLiquid/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ElectronicCigarettesLiquid/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ElectronicCigarettesLiquid/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ElectronicCigarettesLiquid/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Firecracker/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Firecracker/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Firecracker/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Firecracker/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Gun/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Gun/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Gun/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Gun/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/GunParts/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/GunParts/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/GunParts/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/GunParts/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Hammer/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Hammer/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Hammer/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Hammer/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/HandCuffs/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/HandCuffs/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/HandCuffs/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/HandCuffs/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/HDDExternal/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/HDDExternal/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/HDDExternal/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/HDDExternal/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/HDD/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/HDD/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/HDD/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/HDD/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Knife/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Knife/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Knife/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Knife/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/LapTop/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/LapTop/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/LapTop/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/LapTop/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Lighter/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Lighter/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Lighter/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Lighter/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Liquid/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Liquid/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Liquid/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Liquid/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Match/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Match/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Match/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Match/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/MetalPipe/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/MetalPipe/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/MetalPipe/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/MetalPipe/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/NailClippers/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/NailClippers/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/NailClippers/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/NailClippers/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Plier/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Plier/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Plier/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Plier/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/PortableGas/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/PortableGas/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/PortableGas/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/PortableGas/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Saw/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Saw/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Saw/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Saw/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Scissors/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Scissors/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Scissors/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Scissors/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Screwdriver/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Screwdriver/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Screwdriver/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Screwdriver/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SmartPhone/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SmartPhone/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SmartPhone/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SmartPhone/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SolidFuel/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SolidFuel/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SolidFuel/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SolidFuel/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Spanner/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Spanner/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Spanner/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Spanner/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SSD/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SSD/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SSD/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SSD/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SupplymentaryBattery/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SupplymentaryBattery/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SupplymentaryBattery/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SupplymentaryBattery/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/TabletPC/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/TabletPC/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/TabletPC/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/TabletPC/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Thinner/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Thinner/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Thinner/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Thinner/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ThrowingKnife/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ThrowingKnife/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ThrowingKnife/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ThrowingKnife/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/USB/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/USB/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/USB/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/USB/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ZippoOil/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ZippoOil/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ZippoOil/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ZippoOil/Single_Other : file exists
# ====================================================================================================
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Aerosol/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Aerosol/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Aerosol/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Aerosol/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Alcohol/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Alcohol/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Alcohol/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Alcohol/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Awl/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Awl/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Awl/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Awl/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Axe/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Axe/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Axe/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Axe/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Bat/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Bat/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Bat/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Bat/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Battery/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Battery/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Battery/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Battery/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Bullet/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Bullet/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Bullet/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Bullet/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Chisel/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Chisel/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Chisel/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Chisel/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/ElectronicCigarettes/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/ElectronicCigarettes/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/ElectronicCigarettes/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/ElectronicCigarettes/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/ElectronicCigarettesLiquid/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/ElectronicCigarettesLiquid/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/ElectronicCigarettesLiquid/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/ElectronicCigarettesLiquid/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Firecracker/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Firecracker/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Firecracker/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Firecracker/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Gun/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Gun/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Gun/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Gun/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/GunParts/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/GunParts/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/GunParts/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/GunParts/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Hammer/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Hammer/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Hammer/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Hammer/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/HandCuffs/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/HandCuffs/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/HandCuffs/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/HandCuffs/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/HDDExternal/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/HDDExternal/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/HDDExternal/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/HDDExternal/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/HDD/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/HDD/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/HDD/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/HDD/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Knife/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Knife/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Knife/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Knife/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/LapTop/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/LapTop/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/LapTop/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/LapTop/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Lighter/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Lighter/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Lighter/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Lighter/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Liquid/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Liquid/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Liquid/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Liquid/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Match/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Match/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Match/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Match/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/MetalPipe/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/MetalPipe/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/MetalPipe/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/MetalPipe/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/NailClippers/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/NailClippers/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/NailClippers/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/NailClippers/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Plier/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Plier/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Plier/Single_Default : file exists
# ...
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Chisel/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Chisel/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Chisel/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Chisel/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/ElectronicCigarettes/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/ElectronicCigarettes/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/ElectronicCigarettes/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/ElectronicCigarettes/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/ElectronicCigarettesLiquid/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/ElectronicCigarettesLiquid/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/ElectronicCigarettesLiquid/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/ElectronicCigarettesLiquid/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Firecracker/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Firecracker/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Firecracker/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Firecracker/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Gun/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Gun/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Gun/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Gun/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/GunParts/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/GunParts/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/GunParts/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/GunParts/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Hammer/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Hammer/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Hammer/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Hammer/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/HandCuffs/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/HandCuffs/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/HandCuffs/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/HandCuffs/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/HDDExternal/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/HDDExternal/Multiple_Other : XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/HDDExternal/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/HDDExternal/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/HDD/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/HDD/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/HDD/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/HDD/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Knife/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Knife/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Knife/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Knife/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/LapTop/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/LapTop/Multiple_Other XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/LapTop/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/LapTop/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Lighter/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Lighter/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Lighter/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Lighter/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Liquid/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Liquid/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Liquid/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Liquid/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Match/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Match/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Match/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Match/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/MetalPipe/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/MetalPipe/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/MetalPipe/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/MetalPipe/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/NailClippers/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/NailClippers/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/NailClippers/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/NailClippers/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Plier/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Plier/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Plier/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Plier/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/PortableGas/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/PortableGas/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/PortableGas/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/PortableGas/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Saw/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Saw/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Saw/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Saw/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Scissors/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Scissors/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Scissors/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Scissors/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Screwdriver/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Screwdriver/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Screwdriver/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Screwdriver/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SmartPhone/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SmartPhone/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SmartPhone/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SmartPhone/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SolidFuel/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SolidFuel/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SolidFuel/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SolidFuel/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Spanner/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Spanner/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Spanner/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Spanner/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SSD/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SSD/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SSD/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SSD/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SupplymentaryBattery/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SupplymentaryBattery/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SupplymentaryBattery/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SupplymentaryBattery/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/TabletPC/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/TabletPC/Multiple_Other XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/TabletPC/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/TabletPC/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Thinner/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Thinner/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Thinner/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Thinner/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/ThrowingKnife/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/ThrowingKnife/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/ThrowingKnife/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/ThrowingKnife/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/USB/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/USB/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/USB/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/USB/Single_Other : file exists
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/ZippoOil/Multiple_Categories : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/ZippoOil/Multiple_Other : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/ZippoOil/Single_Default : file exists
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/ZippoOil/Single_Other : file exists
# ====================================================================================================
# ====================================================================================================

# %% [markdown]
# ### 디렉토리 내에 png 파일만 존재하는지 확인

# %%
import os
import glob

modes = [
  "Train", 
  "Validation"
]
companies = [
  "Smith",
  "Astrophysics",
  "Rapiscan"
]
classes = [
  "Aerosol", "Alcohol", "Awl", "Axe", "Bat", "Battery", "Bullet", "Chisel", "ElectronicCigarettes",
  "ElectronicCigarettesLiquid", "Firecracker", "Gun", "GunParts", "Hammer", "HandCuffs",
  "HDDExternal", "HDD", "Knife", "LapTop", "Lighter", "Liquid", "Match", "MetalPipe", "NailClippers",
  "Plier", "PortableGas", "Saw", "Scissors", "Screwdriver", "SmartPhone", "SolidFuel", "Spanner",
  "SSD", "SupplymentaryBattery", "TabletPC", "Thinner", "ThrowingKnife", "USB", "ZippoOil"
]
categories = [
  "Multiple_Categories",
  "Multiple_Other",
  "Single_Default",
  "Single_Other"
]

for m in modes:
  for com in companies:
    for cls in classes:
      for ctg in categories:
        path = f"/content/drive/MyDrive/datasets/xray/{m}/{com}/{cls}/{ctg}"
        if os.path.exists(path):
          png_list_len = len(glob.glob(f"{path}/*.png"))
          file_list_len = len(os.listdir(path))
          is_same_size = "same size" if png_list_len == file_list_len else "XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX"
          print(f"{path} : {file_list_len} files, {png_list_len} png files, {is_same_size}")
        else:
          print(path, "XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX") # Validation/Rapiscan/LapTop/Multiple_Other is not exist 
      print("=="*50)
    print("=="*50)
# Out:
# /content/drive/MyDrive/datasets/xray/Train/Smith/Aerosol/Multiple_Categories : 929 files, 929 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Aerosol/Multiple_Other : 700 files, 700 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Aerosol/Single_Default : 280 files, 280 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Aerosol/Single_Other : 350 files, 350 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Alcohol/Multiple_Categories : 335 files, 335 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Alcohol/Multiple_Other : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Alcohol/Single_Default : 125 files, 125 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Alcohol/Single_Other : 125 files, 125 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Awl/Multiple_Categories : 1860 files, 1860 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Awl/Multiple_Other : 1400 files, 1400 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Awl/Single_Default : 700 files, 700 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Awl/Single_Other : 700 files, 700 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Axe/Multiple_Categories : 2140 files, 2140 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Axe/Multiple_Other : 1600 files, 1600 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Axe/Single_Default : 800 files, 800 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Axe/Single_Other : 800 files, 800 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Bat/Multiple_Categories : 670 files, 670 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Bat/Multiple_Other : 500 files, 500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Bat/Single_Default : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Bat/Single_Other : 250 files, 250 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Battery/Multiple_Categories : 335 files, 335 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Battery/Multiple_Other : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Battery/Single_Default : 125 files, 125 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Battery/Single_Other : 125 files, 125 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Bullet/Multiple_Categories : 1605 files, 1605 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Bullet/Multiple_Other : 1200 files, 1200 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Bullet/Single_Default : 600 files, 600 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Bullet/Single_Other : 600 files, 600 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Chisel/Multiple_Categories : 2325 files, 2325 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Chisel/Multiple_Other : 1750 files, 1750 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Chisel/Single_Default : 875 files, 875 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Chisel/Single_Other : 875 files, 875 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/ElectronicCigarettes/Multiple_Categories : 670 files, 670 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/ElectronicCigarettes/Multiple_Other : 500 files, 500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/ElectronicCigarettes/Single_Default : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/ElectronicCigarettes/Single_Other : 250 files, 250 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/ElectronicCigarettesLiquid/Multiple_Categories : 670 files, 670 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/ElectronicCigarettesLiquid/Multiple_Other : 500 files, 500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/ElectronicCigarettesLiquid/Single_Default : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/ElectronicCigarettesLiquid/Single_Other : 250 files, 250 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Firecracker/Multiple_Categories : 2675 files, 2675 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Firecracker/Multiple_Other : 2000 files, 2000 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Firecracker/Single_Default : 1000 files, 1000 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Firecracker/Single_Other : 1000 files, 1000 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Gun/Multiple_Categories : 2140 files, 2140 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Gun/Multiple_Other : 1600 files, 1600 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Gun/Single_Default : 800 files, 800 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Gun/Single_Other : 800 files, 800 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/GunParts/Multiple_Categories : 2675 files, 2675 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/GunParts/Multiple_Other : 2000 files, 2000 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/GunParts/Single_Default : 1000 files, 1000 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/GunParts/Single_Other : 1000 files, 1000 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Hammer/Multiple_Categories : 2138 files, 2138 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Hammer/Multiple_Other : 1600 files, 1600 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Hammer/Single_Default : 800 files, 800 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Hammer/Single_Other : 800 files, 800 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/HandCuffs/Multiple_Categories : 335 files, 335 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/HandCuffs/Multiple_Other : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/HandCuffs/Single_Default : 125 files, 125 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/HandCuffs/Single_Other : 125 files, 125 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/HDDExternal/Multiple_Categories : 335 files, 335 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/HDDExternal/Multiple_Other : 381 files, 381 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/HDDExternal/Single_Default : 125 files, 125 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/HDDExternal/Single_Other : 125 files, 125 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/HDD/Multiple_Categories : 335 files, 335 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/HDD/Multiple_Other : 248 files, 248 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/HDD/Single_Default : 125 files, 125 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/HDD/Single_Other : 125 files, 125 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Knife/Multiple_Categories : 3255 files, 3255 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Knife/Multiple_Other : 2450 files, 2450 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Knife/Single_Default : 1224 files, 1224 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Knife/Single_Other : 1225 files, 1225 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/LapTop/Multiple_Categories : 1340 files, 1340 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/LapTop/Multiple_Other : 1000 files, 1000 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/LapTop/Single_Default : 500 files, 500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/LapTop/Single_Other : 500 files, 500 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Lighter/Multiple_Categories : 2675 files, 2675 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Lighter/Multiple_Other : 2000 files, 2000 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Lighter/Single_Default : 1000 files, 1000 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Lighter/Single_Other : 1000 files, 1000 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Liquid/Multiple_Categories : 1675 files, 1675 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Liquid/Multiple_Other : 1250 files, 1250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Liquid/Single_Default : 625 files, 625 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Liquid/Single_Other : 625 files, 625 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Match/Multiple_Categories : 670 files, 670 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Match/Multiple_Other : 500 files, 500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Match/Single_Default : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Match/Single_Other : 250 files, 250 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/MetalPipe/Multiple_Categories : 1675 files, 1675 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/MetalPipe/Multiple_Other : 1250 files, 1250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/MetalPipe/Single_Default : 625 files, 625 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/MetalPipe/Single_Other : 625 files, 625 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/NailClippers/Multiple_Categories : 1340 files, 1340 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/NailClippers/Multiple_Other : 1000 files, 1000 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/NailClippers/Single_Default : 500 files, 500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/NailClippers/Single_Other : 500 files, 500 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Plier/Multiple_Categories : 1340 files, 1340 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Plier/Multiple_Other : 1000 files, 1000 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Plier/Single_Default : 500 files, 500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Plier/Single_Other : 500 files, 500 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/PortableGas/Multiple_Categories : 930 files, 930 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/PortableGas/Multiple_Other : 700 files, 700 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/PortableGas/Single_Default : 350 files, 350 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/PortableGas/Single_Other : 350 files, 350 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Saw/Multiple_Categories : 3255 files, 3255 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Saw/Multiple_Other : 2450 files, 2450 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Saw/Single_Default : 1225 files, 1225 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Saw/Single_Other : 1225 files, 1225 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Scissors/Multiple_Categories : 3255 files, 3255 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Scissors/Multiple_Other : 2450 files, 2450 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Scissors/Single_Default : 1225 files, 1225 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Scissors/Single_Other : 1225 files, 1225 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Screwdriver/Multiple_Categories : 2000 files, 2000 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Screwdriver/Multiple_Other : 1500 files, 1500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Screwdriver/Single_Default : 750 files, 750 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Screwdriver/Single_Other : 540 files, 540 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/SmartPhone/Multiple_Categories : 1005 files, 1005 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/SmartPhone/Multiple_Other : 823 files, 823 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/SmartPhone/Single_Default : 375 files, 375 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/SmartPhone/Single_Other : 375 files, 375 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/SolidFuel/Multiple_Categories : 670 files, 670 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/SolidFuel/Multiple_Other : 500 files, 500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/SolidFuel/Single_Default : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/SolidFuel/Single_Other : 250 files, 250 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Spanner/Multiple_Categories : 2000 files, 2000 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Spanner/Multiple_Other : 1500 files, 1500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Spanner/Single_Default : 750 files, 750 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Spanner/Single_Other : 750 files, 750 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/SSD/Multiple_Categories : 670 files, 670 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/SSD/Multiple_Other : 500 files, 500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/SSD/Single_Default : 245 files, 245 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/SSD/Single_Other : 250 files, 250 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/SupplymentaryBattery/Multiple_Categories : 2010 files, 2010 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/SupplymentaryBattery/Multiple_Other : 1500 files, 1500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/SupplymentaryBattery/Single_Default : 750 files, 750 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/SupplymentaryBattery/Single_Other : 750 files, 750 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/TabletPC/Multiple_Categories : 670 files, 670 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/TabletPC/Multiple_Other : 544 files, 544 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/TabletPC/Single_Default : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/TabletPC/Single_Other : 250 files, 250 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/Thinner/Multiple_Categories : 335 files, 335 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Thinner/Multiple_Other : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Thinner/Single_Default : 125 files, 125 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/Thinner/Single_Other : 125 files, 125 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/ThrowingKnife/Multiple_Categories : 335 files, 335 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/ThrowingKnife/Multiple_Other : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/ThrowingKnife/Single_Default : 125 files, 125 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/ThrowingKnife/Single_Other : 125 files, 125 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/USB/Multiple_Categories : 1340 files, 1340 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/USB/Multiple_Other : 1000 files, 1000 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/USB/Single_Default : 500 files, 500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/USB/Single_Other : 500 files, 500 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Smith/ZippoOil/Multiple_Categories : 335 files, 335 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/ZippoOil/Multiple_Other : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/ZippoOil/Single_Default : 125 files, 125 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Smith/ZippoOil/Single_Other : 125 files, 125 png files, same size
# ====================================================================================================
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Aerosol/Multiple_Categories : 930 files, 930 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Aerosol/Multiple_Other : 700 files, 700 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Aerosol/Single_Default : 350 files, 350 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Aerosol/Single_Other : 350 files, 350 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Alcohol/Multiple_Categories : 335 files, 335 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Alcohol/Multiple_Other : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Alcohol/Single_Default : 125 files, 125 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Alcohol/Single_Other : 125 files, 125 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Awl/Multiple_Categories : 1860 files, 1860 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Awl/Multiple_Other : 1400 files, 1400 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Awl/Single_Default : 700 files, 700 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Awl/Single_Other : 700 files, 700 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Axe/Multiple_Categories : 2140 files, 2140 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Axe/Multiple_Other : 1600 files, 1600 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Axe/Single_Default : 800 files, 800 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Axe/Single_Other : 800 files, 800 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Bat/Multiple_Categories : 670 files, 670 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Bat/Multiple_Other : 500 files, 500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Bat/Single_Default : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Bat/Single_Other : 250 files, 250 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Battery/Multiple_Categories : 335 files, 335 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Battery/Multiple_Other : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Battery/Single_Default : 125 files, 125 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Battery/Single_Other : 125 files, 125 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Bullet/Multiple_Categories : 1605 files, 1605 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Bullet/Multiple_Other : 1200 files, 1200 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Bullet/Single_Default : 600 files, 600 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Bullet/Single_Other : 600 files, 600 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Chisel/Multiple_Categories : 2325 files, 2325 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Chisel/Multiple_Other : 1750 files, 1750 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Chisel/Single_Default : 875 files, 875 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Chisel/Single_Other : 875 files, 875 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ElectronicCigarettes/Multiple_Categories : 670 files, 670 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ElectronicCigarettes/Multiple_Other : 500 files, 500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ElectronicCigarettes/Single_Default : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ElectronicCigarettes/Single_Other : 250 files, 250 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ElectronicCigarettesLiquid/Multiple_Categories : 670 files, 670 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ElectronicCigarettesLiquid/Multiple_Other : 500 files, 500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ElectronicCigarettesLiquid/Single_Default : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ElectronicCigarettesLiquid/Single_Other : 250 files, 250 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Firecracker/Multiple_Categories : 2675 files, 2675 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Firecracker/Multiple_Other : 2000 files, 2000 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Firecracker/Single_Default : 1000 files, 1000 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Firecracker/Single_Other : 1000 files, 1000 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Gun/Multiple_Categories : 2140 files, 2140 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Gun/Multiple_Other : 1600 files, 1600 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Gun/Single_Default : 800 files, 800 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Gun/Single_Other : 800 files, 800 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/GunParts/Multiple_Categories : 2675 files, 2675 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/GunParts/Multiple_Other : 2000 files, 2000 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/GunParts/Single_Default : 1000 files, 1000 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/GunParts/Single_Other : 1000 files, 1000 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Hammer/Multiple_Categories : 2140 files, 2140 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Hammer/Multiple_Other : 1600 files, 1600 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Hammer/Single_Default : 800 files, 800 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Hammer/Single_Other : 800 files, 800 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/HandCuffs/Multiple_Categories : 335 files, 335 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/HandCuffs/Multiple_Other : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/HandCuffs/Single_Default : 125 files, 125 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/HandCuffs/Single_Other : 125 files, 125 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/HDDExternal/Multiple_Categories : 335 files, 335 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/HDDExternal/Multiple_Other : 318 files, 318 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/HDDExternal/Single_Default : 125 files, 125 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/HDDExternal/Single_Other : 125 files, 125 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/HDD/Multiple_Categories : 335 files, 335 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/HDD/Multiple_Other : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/HDD/Single_Default : 125 files, 125 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/HDD/Single_Other : 125 files, 125 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Knife/Multiple_Categories : 3255 files, 3255 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Knife/Multiple_Other : 2450 files, 2450 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Knife/Single_Default : 1225 files, 1225 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Knife/Single_Other : 1225 files, 1225 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/LapTop/Multiple_Categories : 1339 files, 1339 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/LapTop/Multiple_Other : 1000 files, 1000 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/LapTop/Single_Default : 500 files, 500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/LapTop/Single_Other : 500 files, 500 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Lighter/Multiple_Categories : 2675 files, 2675 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Lighter/Multiple_Other : 2000 files, 2000 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Lighter/Single_Default : 1000 files, 1000 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Lighter/Single_Other : 1000 files, 1000 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Liquid/Multiple_Categories : 1675 files, 1675 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Liquid/Multiple_Other : 1250 files, 1250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Liquid/Single_Default : 625 files, 625 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Liquid/Single_Other : 625 files, 625 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Match/Multiple_Categories : 670 files, 670 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Match/Multiple_Other : 500 files, 500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Match/Single_Default : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Match/Single_Other : 250 files, 250 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/MetalPipe/Multiple_Categories : 1675 files, 1675 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/MetalPipe/Multiple_Other : 1250 files, 1250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/MetalPipe/Single_Default : 625 files, 625 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/MetalPipe/Single_Other : 625 files, 625 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/NailClippers/Multiple_Categories : 1340 files, 1340 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/NailClippers/Multiple_Other : 1000 files, 1000 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/NailClippers/Single_Default : 500 files, 500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/NailClippers/Single_Other : 500 files, 500 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Plier/Multiple_Categories : 1340 files, 1340 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Plier/Multiple_Other : 1000 files, 1000 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Plier/Single_Default : 500 files, 500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Plier/Single_Other : 500 files, 500 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/PortableGas/Multiple_Categories : 930 files, 930 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/PortableGas/Multiple_Other : 700 files, 700 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/PortableGas/Single_Default : 350 files, 350 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/PortableGas/Single_Other : 350 files, 350 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Saw/Multiple_Categories : 3255 files, 3255 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Saw/Multiple_Other : 2450 files, 2450 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Saw/Single_Default : 1225 files, 1225 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Saw/Single_Other : 1225 files, 1225 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Scissors/Multiple_Categories : 3255 files, 3255 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Scissors/Multiple_Other : 2450 files, 2450 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Scissors/Single_Default : 1225 files, 1225 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Scissors/Single_Other : 1225 files, 1225 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Screwdriver/Multiple_Categories : 2000 files, 2000 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Screwdriver/Multiple_Other : 1500 files, 1500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Screwdriver/Single_Default : 750 files, 750 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Screwdriver/Single_Other : 750 files, 750 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SmartPhone/Multiple_Categories : 1005 files, 1005 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SmartPhone/Multiple_Other : 750 files, 750 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SmartPhone/Single_Default : 375 files, 375 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SmartPhone/Single_Other : 375 files, 375 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SolidFuel/Multiple_Categories : 670 files, 670 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SolidFuel/Multiple_Other : 500 files, 500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SolidFuel/Single_Default : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SolidFuel/Single_Other : 250 files, 250 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Spanner/Multiple_Categories : 2000 files, 2000 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Spanner/Multiple_Other : 1500 files, 1500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Spanner/Single_Default : 750 files, 750 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Spanner/Single_Other : 750 files, 750 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SSD/Multiple_Categories : 668 files, 668 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SSD/Multiple_Other : 500 files, 500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SSD/Single_Default : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SSD/Single_Other : 250 files, 250 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SupplymentaryBattery/Multiple_Categories : 2009 files, 2009 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SupplymentaryBattery/Multiple_Other : 1500 files, 1500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SupplymentaryBattery/Single_Default : 750 files, 750 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/SupplymentaryBattery/Single_Other : 750 files, 750 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/TabletPC/Multiple_Categories : 670 files, 670 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/TabletPC/Multiple_Other : 598 files, 598 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/TabletPC/Single_Default : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/TabletPC/Single_Other : 250 files, 250 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Thinner/Multiple_Categories : 335 files, 335 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Thinner/Multiple_Other : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Thinner/Single_Default : 125 files, 125 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/Thinner/Single_Other : 125 files, 125 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ThrowingKnife/Multiple_Categories : 335 files, 335 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ThrowingKnife/Multiple_Other : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ThrowingKnife/Single_Default : 125 files, 125 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ThrowingKnife/Single_Other : 125 files, 125 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/USB/Multiple_Categories : 1340 files, 1340 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/USB/Multiple_Other : 1000 files, 1000 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/USB/Single_Default : 500 files, 500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/USB/Single_Other : 500 files, 500 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ZippoOil/Multiple_Categories : 335 files, 335 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ZippoOil/Multiple_Other : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ZippoOil/Single_Default : 125 files, 125 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Astrophysics/ZippoOil/Single_Other : 125 files, 125 png files, same size
# ====================================================================================================
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Aerosol/Multiple_Categories : 929 files, 929 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Aerosol/Multiple_Other : 700 files, 700 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Aerosol/Single_Default : 350 files, 350 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Aerosol/Single_Other : 350 files, 350 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Alcohol/Multiple_Categories : 335 files, 335 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Alcohol/Multiple_Other : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Alcohol/Single_Default : 125 files, 125 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Alcohol/Single_Other : 125 files, 125 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Awl/Multiple_Categories : 1860 files, 1860 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Awl/Multiple_Other : 1400 files, 1400 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Awl/Single_Default : 700 files, 700 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Awl/Single_Other : 700 files, 700 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Axe/Multiple_Categories : 2139 files, 2139 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Axe/Multiple_Other : 1600 files, 1600 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Axe/Single_Default : 800 files, 800 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Axe/Single_Other : 800 files, 800 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Bat/Multiple_Categories : 670 files, 670 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Bat/Multiple_Other : 500 files, 500 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Bat/Single_Default : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Bat/Single_Other : 250 files, 250 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Battery/Multiple_Categories : 335 files, 335 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Battery/Multiple_Other : 250 files, 250 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Battery/Single_Default : 125 files, 125 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Battery/Single_Other : 125 files, 125 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Bullet/Multiple_Categories : 1605 files, 1605 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Bullet/Multiple_Other : 1200 files, 1200 png files, same size
# /content/drive/MyDrive/datasets/xray/Train/Rapiscan/Bullet/Single_Default : 600 files, 600 png files, same size
# ...
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Gun/Single_Other : 86 files, 86 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/GunParts/Multiple_Categories : 125 files, 125 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/GunParts/Multiple_Other : 100 files, 100 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/GunParts/Single_Default : 100 files, 100 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/GunParts/Single_Other : 100 files, 100 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Hammer/Multiple_Categories : 2428 files, 2428 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Hammer/Multiple_Other : 1864 files, 1864 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Hammer/Single_Default : 976 files, 976 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Hammer/Single_Other : 976 files, 976 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/HandCuffs/Multiple_Categories : 25 files, 25 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/HandCuffs/Multiple_Other : 30 files, 30 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/HandCuffs/Single_Default : 15 files, 15 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/HandCuffs/Single_Other : 15 files, 15 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/HDDExternal/Multiple_Categories : 20 files, 20 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/HDDExternal/Multiple_Other : 0 files, 0 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/HDDExternal/Single_Default : 28 files, 28 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/HDDExternal/Single_Other : 17 files, 17 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/HDD/Multiple_Categories : 27 files, 27 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/HDD/Multiple_Other : 27 files, 27 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/HDD/Single_Default : 17 files, 17 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/HDD/Single_Other : 18 files, 18 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Knife/Multiple_Categories : 2007 files, 2007 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Knife/Multiple_Other : 1470 files, 1470 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Knife/Single_Default : 1535 files, 1535 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Knife/Single_Other : 883 files, 883 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/LapTop/Multiple_Categories : 111 files, 111 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/LapTop/Multiple_Other XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/LapTop/Single_Default : 70 files, 70 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/LapTop/Single_Other : 72 files, 72 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Lighter/Multiple_Categories : 141 files, 141 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Lighter/Multiple_Other : 108 files, 108 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Lighter/Single_Default : 718 files, 718 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Lighter/Single_Other : 710 files, 710 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Liquid/Multiple_Categories : 127 files, 127 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Liquid/Multiple_Other : 98 files, 98 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Liquid/Single_Default : 341 files, 341 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Liquid/Single_Other : 345 files, 345 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Match/Multiple_Categories : 50 files, 50 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Match/Multiple_Other : 60 files, 60 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Match/Single_Default : 30 files, 30 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Match/Single_Other : 30 files, 30 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/MetalPipe/Multiple_Categories : 125 files, 125 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/MetalPipe/Multiple_Other : 136 files, 136 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/MetalPipe/Single_Default : 75 files, 75 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/MetalPipe/Single_Other : 77 files, 77 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/NailClippers/Multiple_Categories : 100 files, 100 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/NailClippers/Multiple_Other : 120 files, 120 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/NailClippers/Single_Default : 100 files, 100 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/NailClippers/Single_Other : 100 files, 100 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Plier/Multiple_Categories : 106 files, 106 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Plier/Multiple_Other : 94 files, 94 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Plier/Single_Default : 110 files, 110 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Plier/Single_Other : 70 files, 70 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/PortableGas/Multiple_Categories : 78 files, 78 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/PortableGas/Multiple_Other : 64 files, 64 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/PortableGas/Single_Default : 58 files, 58 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/PortableGas/Single_Other : 50 files, 50 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Saw/Multiple_Categories : 187 files, 187 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Saw/Multiple_Other : 226 files, 226 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Saw/Single_Default : 175 files, 175 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Saw/Single_Other : 179 files, 179 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Scissors/Multiple_Categories : 221 files, 221 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Scissors/Multiple_Other : 226 files, 226 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Scissors/Single_Default : 185 files, 185 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Scissors/Single_Other : 175 files, 175 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Screwdriver/Multiple_Categories : 100 files, 100 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Screwdriver/Multiple_Other : 100 files, 100 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Screwdriver/Single_Default : 270 files, 270 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Screwdriver/Single_Other : 276 files, 276 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SmartPhone/Multiple_Categories : 83 files, 83 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SmartPhone/Multiple_Other : 56 files, 56 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SmartPhone/Single_Default : 80 files, 80 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SmartPhone/Single_Other : 79 files, 79 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SolidFuel/Multiple_Categories : 50 files, 50 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SolidFuel/Multiple_Other : 60 files, 60 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SolidFuel/Single_Default : 30 files, 30 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SolidFuel/Single_Other : 30 files, 30 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Spanner/Multiple_Categories : 108 files, 108 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Spanner/Multiple_Other : 98 files, 98 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Spanner/Single_Default : 340 files, 340 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Spanner/Single_Other : 336 files, 336 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SSD/Multiple_Categories : 68 files, 68 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SSD/Multiple_Other : 48 files, 48 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SSD/Single_Default : 33 files, 33 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SSD/Single_Other : 30 files, 30 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SupplymentaryBattery/Multiple_Categories : 152 files, 152 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SupplymentaryBattery/Multiple_Other : 148 files, 148 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SupplymentaryBattery/Single_Default : 568 files, 568 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/SupplymentaryBattery/Single_Other : 568 files, 568 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/TabletPC/Multiple_Categories : 63 files, 63 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/TabletPC/Multiple_Other XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/TabletPC/Single_Default : 38 files, 38 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/TabletPC/Single_Other : 45 files, 45 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Thinner/Multiple_Categories : 25 files, 25 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Thinner/Multiple_Other : 30 files, 30 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Thinner/Single_Default : 25 files, 25 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/Thinner/Single_Other : 25 files, 25 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/ThrowingKnife/Multiple_Categories : 25 files, 25 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/ThrowingKnife/Multiple_Other : 30 files, 30 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/ThrowingKnife/Single_Default : 15 files, 15 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/ThrowingKnife/Single_Other : 15 files, 15 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/USB/Multiple_Categories : 305 files, 305 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/USB/Multiple_Other : 94 files, 94 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/USB/Single_Default : 96 files, 96 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/USB/Single_Other : 95 files, 95 png files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/ZippoOil/Multiple_Categories : 25 files, 25 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/ZippoOil/Multiple_Other : 30 files, 30 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/ZippoOil/Single_Default : 15 files, 15 png files, same size
# /content/drive/MyDrive/datasets/xray/Validation/Rapiscan/ZippoOil/Single_Other : 15 files, 15 png files, same size
# ====================================================================================================
# ====================================================================================================

# %% [markdown]
# ### 디렉토리 내에 txt 파일만 존재하는지 확인

# %%
import os
import glob

modes = [
  "Train", 
  "Validation"
]
companies = [
  "Smith",
  "Astrophysics",
  "Rapiscan"
]
classes = [
  "Aerosol", "Alcohol", "Awl", "Axe", "Bat", "Battery", "Bullet", "Chisel", "ElectronicCigarettes",
  "ElectronicCigarettesLiquid", "Firecracker", "Gun", "GunParts", "Hammer", "HandCuffs",
  "HDDExternal", "HDD", "Knife", "LapTop", "Lighter", "Liquid", "Match", "MetalPipe", "NailClippers",
  "Plier", "PortableGas", "Saw", "Scissors", "Screwdriver", "SmartPhone", "SolidFuel", "Spanner",
  "SSD", "SupplymentaryBattery", "TabletPC", "Thinner", "ThrowingKnife", "USB", "ZippoOil"
]
categories = [
  "Multiple_Categories",
  "Multiple_Other",
  "Single_Default",
  "Single_Other"
]

for m in modes:
  for com in companies:
    for cls in classes:
      for ctg in categories:
        path = f"/content/drive/MyDrive/datasets/xray/Annotation/{m}/{com}/{cls}/{ctg}"
        if os.path.exists(path):
          txt_list_len = len(glob.glob(f"{path}/*.txt"))
          file_list_len = len(os.listdir(path))
          is_same_size = "same size" if txt_list_len == file_list_len else "different size XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX"
          print(f"{path} : {file_list_len} files, {txt_list_len} txt files, {is_same_size}")
        else:
          print(path, "is not exist...") # Validation/Rapiscan/LapTop/Multiple_Other is not exist 
      print("=="*50)
    print("=="*50)
# Out:
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Aerosol/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Aerosol/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Aerosol/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Aerosol/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Alcohol/Multiple_Categories : 335 files, 335 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Alcohol/Multiple_Other : 250 files, 250 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Alcohol/Single_Default : 125 files, 125 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Alcohol/Single_Other : 125 files, 125 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Awl/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Awl/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Awl/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Awl/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Axe/Multiple_Categories : 2140 files, 2140 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Axe/Multiple_Other : 1600 files, 1600 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Axe/Single_Default : 800 files, 800 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Axe/Single_Other : 800 files, 800 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Bat/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Bat/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Bat/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Bat/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Battery/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Battery/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Battery/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Battery/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Bullet/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Bullet/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Bullet/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Bullet/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Chisel/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Chisel/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Chisel/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Chisel/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/ElectronicCigarettes/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/ElectronicCigarettes/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/ElectronicCigarettes/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/ElectronicCigarettes/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/ElectronicCigarettesLiquid/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/ElectronicCigarettesLiquid/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/ElectronicCigarettesLiquid/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/ElectronicCigarettesLiquid/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Firecracker/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Firecracker/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Firecracker/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Firecracker/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Gun/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Gun/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Gun/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Gun/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/GunParts/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/GunParts/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/GunParts/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/GunParts/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Hammer/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Hammer/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Hammer/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Hammer/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/HandCuffs/Multiple_Categories : 335 files, 335 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/HandCuffs/Multiple_Other : 250 files, 250 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/HandCuffs/Single_Default : 125 files, 125 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/HandCuffs/Single_Other : 125 files, 125 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/HDDExternal/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/HDDExternal/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/HDDExternal/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/HDDExternal/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/HDD/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/HDD/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/HDD/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/HDD/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Knife/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Knife/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Knife/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Knife/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/LapTop/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/LapTop/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/LapTop/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/LapTop/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Lighter/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Lighter/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Lighter/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Lighter/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Liquid/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Liquid/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Liquid/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Liquid/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Match/Multiple_Categories : 670 files, 670 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Match/Multiple_Other : 500 files, 500 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Match/Single_Default : 250 files, 250 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Match/Single_Other : 250 files, 250 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/MetalPipe/Multiple_Categories : 1675 files, 1675 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/MetalPipe/Multiple_Other : 1250 files, 1250 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/MetalPipe/Single_Default : 625 files, 625 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/MetalPipe/Single_Other : 625 files, 625 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/NailClippers/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/NailClippers/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/NailClippers/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/NailClippers/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Plier/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Plier/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Plier/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Plier/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/PortableGas/Multiple_Categories : 930 files, 930 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/PortableGas/Multiple_Other : 700 files, 700 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/PortableGas/Single_Default : 350 files, 350 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/PortableGas/Single_Other : 350 files, 350 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Saw/Multiple_Categories : 3212 files, 3212 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Saw/Multiple_Other : 2417 files, 2417 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Saw/Single_Default : 1204 files, 1204 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Saw/Single_Other : 1214 files, 1214 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Scissors/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Scissors/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Scissors/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Scissors/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Screwdriver/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Screwdriver/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Screwdriver/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Screwdriver/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SmartPhone/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SmartPhone/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SmartPhone/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SmartPhone/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SolidFuel/Multiple_Categories : 669 files, 669 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SolidFuel/Multiple_Other : 500 files, 500 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SolidFuel/Single_Default : 250 files, 250 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SolidFuel/Single_Other : 250 files, 250 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Spanner/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Spanner/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Spanner/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Spanner/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SupplymentaryBattery/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SupplymentaryBattery/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SupplymentaryBattery/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SupplymentaryBattery/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/TabletPC/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/TabletPC/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/TabletPC/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/TabletPC/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Thinner/Multiple_Categories : 335 files, 335 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Thinner/Multiple_Other : 250 files, 250 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Thinner/Single_Default : 125 files, 125 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Thinner/Single_Other : 125 files, 125 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/ThrowingKnife/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/ThrowingKnife/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/ThrowingKnife/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/ThrowingKnife/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/USB/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/USB/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/USB/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/USB/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/ZippoOil/Multiple_Categories : 335 files, 335 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/ZippoOil/Multiple_Other : 250 files, 250 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/ZippoOil/Single_Default : 125 files, 125 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/ZippoOil/Single_Other : 125 files, 125 txt files, same size
# ====================================================================================================
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Aerosol/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Aerosol/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Aerosol/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Aerosol/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Alcohol/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Alcohol/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Alcohol/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Alcohol/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Awl/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Awl/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Awl/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Awl/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Axe/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Axe/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Axe/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Axe/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Bat/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Bat/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Bat/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Bat/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Battery/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Battery/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Battery/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Battery/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Bullet/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Bullet/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Bullet/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Bullet/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Chisel/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Chisel/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Chisel/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Chisel/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/ElectronicCigarettes/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/ElectronicCigarettes/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/ElectronicCigarettes/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/ElectronicCigarettes/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/ElectronicCigarettesLiquid/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/ElectronicCigarettesLiquid/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/ElectronicCigarettesLiquid/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/ElectronicCigarettesLiquid/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Firecracker/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Firecracker/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Firecracker/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Firecracker/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Gun/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Gun/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Gun/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Gun/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/GunParts/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/GunParts/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/GunParts/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/GunParts/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Hammer/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Hammer/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Hammer/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Hammer/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/HandCuffs/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/HandCuffs/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/HandCuffs/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/HandCuffs/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/HDDExternal/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/HDDExternal/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/HDDExternal/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/HDDExternal/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/HDD/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/HDD/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/HDD/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/HDD/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Knife/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Knife/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Knife/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Knife/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/LapTop/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/LapTop/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/LapTop/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/LapTop/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Lighter/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Lighter/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Lighter/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Lighter/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Liquid/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Liquid/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Liquid/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Liquid/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Match/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Match/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Match/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Match/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/MetalPipe/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/MetalPipe/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/MetalPipe/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/MetalPipe/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/NailClippers/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/NailClippers/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/NailClippers/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/NailClippers/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Plier/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Plier/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Plier/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Plier/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/PortableGas/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/PortableGas/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/PortableGas/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/PortableGas/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Saw/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Saw/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Saw/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Saw/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Scissors/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Scissors/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Scissors/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Scissors/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Screwdriver/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Screwdriver/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Screwdriver/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Screwdriver/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/SmartPhone/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/SmartPhone/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/SmartPhone/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/SmartPhone/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/SolidFuel/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/SolidFuel/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/SolidFuel/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/SolidFuel/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Spanner/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Spanner/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Spanner/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Spanner/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/SSD/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/SSD/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/SSD/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/SSD/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/SupplymentaryBattery/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/SupplymentaryBattery/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/SupplymentaryBattery/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/SupplymentaryBattery/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/TabletPC/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/TabletPC/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/TabletPC/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/TabletPC/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Thinner/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Thinner/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Thinner/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/Thinner/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/ThrowingKnife/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/ThrowingKnife/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/ThrowingKnife/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/ThrowingKnife/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/USB/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/USB/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/USB/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/USB/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/ZippoOil/Multiple_Categories : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/ZippoOil/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/ZippoOil/Single_Default : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Astrophysics/ZippoOil/Single_Other : 0 files, 0 txt files, same size
# ====================================================================================================
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Rapiscan/Aerosol/Multiple_Categories : 929 files, 929 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Rapiscan/Aerosol/Multiple_Other : 700 files, 700 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Rapiscan/Aerosol/Single_Default : 350 files, 350 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Rapiscan/Aerosol/Single_Other : 350 files, 350 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Rapiscan/Alcohol/Multiple_Categories : 335 files, 335 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Rapiscan/Alcohol/Multiple_Other : 250 files, 250 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Rapiscan/Alcohol/Single_Default : 125 files, 125 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Rapiscan/Alcohol/Single_Other : 125 files, 125 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Rapiscan/Awl/Multiple_Categories : 1860 files, 1860 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Rapiscan/Awl/Multiple_Other : 1400 files, 1400 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Rapiscan/Awl/Single_Default : 700 files, 700 txt files, same size
# ...
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Hammer/Single_Default : 976 files, 976 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Hammer/Single_Other : 976 files, 976 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/HandCuffs/Multiple_Categories : 25 files, 25 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/HandCuffs/Multiple_Other : 30 files, 30 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/HandCuffs/Single_Default : 15 files, 15 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/HandCuffs/Single_Other : 15 files, 15 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/HDDExternal/Multiple_Categories : 20 files, 20 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/HDDExternal/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/HDDExternal/Single_Default : 28 files, 28 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/HDDExternal/Single_Other : 17 files, 17 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/HDD/Multiple_Categories : 27 files, 27 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/HDD/Multiple_Other : 27 files, 27 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/HDD/Single_Default : 17 files, 17 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/HDD/Single_Other : 18 files, 18 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Knife/Multiple_Categories : 2007 files, 2007 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Knife/Multiple_Other : 1470 files, 1470 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Knife/Single_Default : 1535 files, 1535 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Knife/Single_Other : 883 files, 883 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/LapTop/Multiple_Categories : 111 files, 111 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/LapTop/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/LapTop/Single_Default : 70 files, 70 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/LapTop/Single_Other : 72 files, 72 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Lighter/Multiple_Categories : 141 files, 141 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Lighter/Multiple_Other : 108 files, 108 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Lighter/Single_Default : 718 files, 718 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Lighter/Single_Other : 710 files, 710 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Liquid/Multiple_Categories : 127 files, 127 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Liquid/Multiple_Other : 98 files, 98 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Liquid/Single_Default : 341 files, 341 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Liquid/Single_Other : 345 files, 345 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Match/Multiple_Categories : 50 files, 50 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Match/Multiple_Other : 60 files, 60 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Match/Single_Default : 30 files, 30 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Match/Single_Other : 30 files, 30 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/MetalPipe/Multiple_Categories : 125 files, 125 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/MetalPipe/Multiple_Other : 136 files, 136 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/MetalPipe/Single_Default : 75 files, 75 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/MetalPipe/Single_Other : 77 files, 77 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/NailClippers/Multiple_Categories : 100 files, 100 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/NailClippers/Multiple_Other : 120 files, 120 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/NailClippers/Single_Default : 100 files, 100 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/NailClippers/Single_Other : 100 files, 100 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Plier/Multiple_Categories : 106 files, 106 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Plier/Multiple_Other : 94 files, 94 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Plier/Single_Default : 110 files, 110 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Plier/Single_Other : 70 files, 70 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/PortableGas/Multiple_Categories : 78 files, 78 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/PortableGas/Multiple_Other : 64 files, 64 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/PortableGas/Single_Default : 58 files, 58 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/PortableGas/Single_Other : 50 files, 50 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Saw/Multiple_Categories : 187 files, 187 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Saw/Multiple_Other : 226 files, 226 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Saw/Single_Default : 175 files, 175 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Saw/Single_Other : 179 files, 179 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Scissors/Multiple_Categories : 221 files, 221 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Scissors/Multiple_Other : 226 files, 226 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Scissors/Single_Default : 185 files, 185 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Scissors/Single_Other : 175 files, 175 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Screwdriver/Multiple_Categories : 100 files, 100 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Screwdriver/Multiple_Other : 100 files, 100 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Screwdriver/Single_Default : 270 files, 270 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Screwdriver/Single_Other : 276 files, 276 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/SmartPhone/Multiple_Categories : 83 files, 83 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/SmartPhone/Multiple_Other : 56 files, 56 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/SmartPhone/Single_Default : 80 files, 80 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/SmartPhone/Single_Other : 79 files, 79 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/SolidFuel/Multiple_Categories : 50 files, 50 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/SolidFuel/Multiple_Other : 60 files, 60 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/SolidFuel/Single_Default : 30 files, 30 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/SolidFuel/Single_Other : 30 files, 30 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Spanner/Multiple_Categories : 108 files, 108 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Spanner/Multiple_Other : 98 files, 98 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Spanner/Single_Default : 340 files, 340 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Spanner/Single_Other : 336 files, 336 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/SSD/Multiple_Categories : 68 files, 68 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/SSD/Multiple_Other : 48 files, 48 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/SSD/Single_Default : 33 files, 33 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/SSD/Single_Other : 30 files, 30 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/SupplymentaryBattery/Multiple_Categories : 152 files, 152 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/SupplymentaryBattery/Multiple_Other : 148 files, 148 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/SupplymentaryBattery/Single_Default : 568 files, 568 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/SupplymentaryBattery/Single_Other : 568 files, 568 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/TabletPC/Multiple_Categories : 63 files, 63 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/TabletPC/Multiple_Other : 0 files, 0 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/TabletPC/Single_Default : 38 files, 38 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/TabletPC/Single_Other : 45 files, 45 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Thinner/Multiple_Categories : 25 files, 25 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Thinner/Multiple_Other : 30 files, 30 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Thinner/Single_Default : 25 files, 25 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/Thinner/Single_Other : 25 files, 25 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/ThrowingKnife/Multiple_Categories : 25 files, 25 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/ThrowingKnife/Multiple_Other : 30 files, 30 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/ThrowingKnife/Single_Default : 15 files, 15 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/ThrowingKnife/Single_Other : 15 files, 15 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/USB/Multiple_Categories : 305 files, 305 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/USB/Multiple_Other : 94 files, 94 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/USB/Single_Default : 96 files, 96 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/USB/Single_Other : 95 files, 95 txt files, same size
# ====================================================================================================
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/ZippoOil/Multiple_Categories : 25 files, 25 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/ZippoOil/Multiple_Other : 30 files, 30 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/ZippoOil/Single_Default : 15 files, 15 txt files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/ZippoOil/Single_Other : 15 files, 15 txt files, same size
# ====================================================================================================
# ====================================================================================================

# %% [markdown]
# ### 어노테이션과 이미지가 같은 개수인지 파악함

# %%
import os
import glob

modes = [
  "Train", 
  "Validation"
]
companies = [
  "Smith",
  "Astrophysics",
  "Rapiscan"
]
classes = [
  "Aerosol", "Alcohol", "Awl", "Axe", "Bat", "Battery", "Bullet", "Chisel", "ElectronicCigarettes",
  "ElectronicCigarettesLiquid", "Firecracker", "Gun", "GunParts", "Hammer", "HandCuffs",
  "HDDExternal", "HDD", "Knife", "LapTop", "Lighter", "Liquid", "Match", "MetalPipe", "NailClippers",
  "Plier", "PortableGas", "Saw", "Scissors", "Screwdriver", "SmartPhone", "SolidFuel", "Spanner",
  "SSD", "SupplymentaryBattery", "TabletPC", "Thinner", "ThrowingKnife", "USB", "ZippoOil"
]
categories = [
  "Multiple_Categories",
  "Multiple_Other",
  "Single_Default",
  "Single_Other"
]

for m in modes:
  for com in companies:
    for cls in classes:
      for ctg in categories:
        png_path = f"/content/drive/MyDrive/datasets/xray/{m}/{com}/{cls}/{ctg}"
        anno_path = f"/content/drive/MyDrive/datasets/xray/Annotation/{m}/{com}/{cls}/{ctg}"
        if os.path.exists(png_path) and os.path.exists(anno_path):
          png_len = len(os.listdir(png_path))
          anno_len = len(os.listdir(anno_path))
          is_same_size = "same size" if png_len <= anno_len else "XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX"
          print(f"./{m}/{com}/{cls}/{ctg} : {png_len} png files, {anno_len} anno files, {is_same_size}")
        else:
          if os.path.exists(png_path):
            print(png_path, "is not exist...")
          if os.path.exists(anno_path):
            print(anno_path, "is not exist...")
      print("=="*50)
    print("=="*50)
# Out:
# ./Train/Smith/Aerosol/Multiple_Categories : 929 png files, 930 anno files, same size
# ./Train/Smith/Aerosol/Multiple_Other : 700 png files, 700 anno files, same size
# ./Train/Smith/Aerosol/Single_Default : 280 png files, 280 anno files, same size
# ./Train/Smith/Aerosol/Single_Other : 350 png files, 350 anno files, same size
# ====================================================================================================
# ./Train/Smith/Alcohol/Multiple_Categories : 335 png files, 335 anno files, same size
# ./Train/Smith/Alcohol/Multiple_Other : 250 png files, 250 anno files, same size
# ./Train/Smith/Alcohol/Single_Default : 125 png files, 125 anno files, same size
# ./Train/Smith/Alcohol/Single_Other : 125 png files, 125 anno files, same size
# ====================================================================================================
# ./Train/Smith/Awl/Multiple_Categories : 1860 png files, 1860 anno files, same size
# ./Train/Smith/Awl/Multiple_Other : 1400 png files, 1400 anno files, same size
# ./Train/Smith/Awl/Single_Default : 700 png files, 700 anno files, same size
# ./Train/Smith/Awl/Single_Other : 700 png files, 700 anno files, same size
# ====================================================================================================
# ./Train/Smith/Axe/Multiple_Categories : 2140 png files, 2140 anno files, same size
# ./Train/Smith/Axe/Multiple_Other : 1600 png files, 1600 anno files, same size
# ./Train/Smith/Axe/Single_Default : 800 png files, 800 anno files, same size
# ./Train/Smith/Axe/Single_Other : 800 png files, 800 anno files, same size
# ====================================================================================================
# ./Train/Smith/Bat/Multiple_Categories : 670 png files, 670 anno files, same size
# ./Train/Smith/Bat/Multiple_Other : 500 png files, 500 anno files, same size
# ./Train/Smith/Bat/Single_Default : 250 png files, 250 anno files, same size
# ./Train/Smith/Bat/Single_Other : 250 png files, 250 anno files, same size
# ====================================================================================================
# ./Train/Smith/Battery/Multiple_Categories : 335 png files, 335 anno files, same size
# ./Train/Smith/Battery/Multiple_Other : 250 png files, 250 anno files, same size
# ./Train/Smith/Battery/Single_Default : 125 png files, 125 anno files, same size
# ./Train/Smith/Battery/Single_Other : 125 png files, 125 anno files, same size
# ====================================================================================================
# ./Train/Smith/Bullet/Multiple_Categories : 1605 png files, 1605 anno files, same size
# ./Train/Smith/Bullet/Multiple_Other : 1200 png files, 1200 anno files, same size
# ./Train/Smith/Bullet/Single_Default : 600 png files, 600 anno files, same size
# ./Train/Smith/Bullet/Single_Other : 594 png files, 594 anno files, same size
# ====================================================================================================
# ./Train/Smith/Chisel/Multiple_Categories : 2325 png files, 2325 anno files, same size
# ./Train/Smith/Chisel/Multiple_Other : 1750 png files, 1750 anno files, same size
# ./Train/Smith/Chisel/Single_Default : 875 png files, 875 anno files, same size
# ./Train/Smith/Chisel/Single_Other : 875 png files, 875 anno files, same size
# ====================================================================================================
# ./Train/Smith/ElectronicCigarettes/Multiple_Categories : 670 png files, 670 anno files, same size
# ./Train/Smith/ElectronicCigarettes/Multiple_Other : 500 png files, 500 anno files, same size
# ./Train/Smith/ElectronicCigarettes/Single_Default : 250 png files, 250 anno files, same size
# ./Train/Smith/ElectronicCigarettes/Single_Other : 250 png files, 250 anno files, same size
# ====================================================================================================
# ./Train/Smith/ElectronicCigarettesLiquid/Multiple_Categories : 670 png files, 670 anno files, same size
# ./Train/Smith/ElectronicCigarettesLiquid/Multiple_Other : 500 png files, 500 anno files, same size
# ./Train/Smith/ElectronicCigarettesLiquid/Single_Default : 250 png files, 250 anno files, same size
# ./Train/Smith/ElectronicCigarettesLiquid/Single_Other : 250 png files, 250 anno files, same size
# ====================================================================================================
# ./Train/Smith/Firecracker/Multiple_Categories : 2675 png files, 2675 anno files, same size
# ./Train/Smith/Firecracker/Multiple_Other : 2000 png files, 2000 anno files, same size
# ./Train/Smith/Firecracker/Single_Default : 1000 png files, 1000 anno files, same size
# ./Train/Smith/Firecracker/Single_Other : 1000 png files, 1000 anno files, same size
# ====================================================================================================
# ./Train/Smith/Gun/Multiple_Categories : 2140 png files, 2140 anno files, same size
# ./Train/Smith/Gun/Multiple_Other : 1600 png files, 1600 anno files, same size
# ./Train/Smith/Gun/Single_Default : 800 png files, 800 anno files, same size
# ./Train/Smith/Gun/Single_Other : 800 png files, 800 anno files, same size
# ====================================================================================================
# ./Train/Smith/GunParts/Multiple_Categories : 2675 png files, 2675 anno files, same size
# ./Train/Smith/GunParts/Multiple_Other : 2000 png files, 2000 anno files, same size
# ./Train/Smith/GunParts/Single_Default : 998 png files, 998 anno files, same size
# ./Train/Smith/GunParts/Single_Other : 1000 png files, 1000 anno files, same size
# ====================================================================================================
# ./Train/Smith/Hammer/Multiple_Categories : 2138 png files, 2138 anno files, same size
# ./Train/Smith/Hammer/Multiple_Other : 1600 png files, 1600 anno files, same size
# ./Train/Smith/Hammer/Single_Default : 800 png files, 800 anno files, same size
# ./Train/Smith/Hammer/Single_Other : 800 png files, 800 anno files, same size
# ====================================================================================================
# ./Train/Smith/HandCuffs/Multiple_Categories : 335 png files, 335 anno files, same size
# ./Train/Smith/HandCuffs/Multiple_Other : 250 png files, 250 anno files, same size
# ./Train/Smith/HandCuffs/Single_Default : 125 png files, 125 anno files, same size
# ./Train/Smith/HandCuffs/Single_Other : 125 png files, 125 anno files, same size
# ====================================================================================================
# ./Train/Smith/HDDExternal/Multiple_Categories : 335 png files, 378 anno files, same size
# ./Train/Smith/HDDExternal/Multiple_Other : 381 png files, 381 anno files, same size
# ./Train/Smith/HDDExternal/Single_Default : 125 png files, 161 anno files, same size
# ./Train/Smith/HDDExternal/Single_Other : 125 png files, 158 anno files, same size
# ====================================================================================================
# ./Train/Smith/HDD/Multiple_Categories : 335 png files, 335 anno files, same size
# ./Train/Smith/HDD/Multiple_Other : 248 png files, 248 anno files, same size
# ./Train/Smith/HDD/Single_Default : 125 png files, 125 anno files, same size
# ./Train/Smith/HDD/Single_Other : 125 png files, 125 anno files, same size
# ====================================================================================================
# ./Train/Smith/Knife/Multiple_Categories : 3255 png files, 3255 anno files, same size
# ./Train/Smith/Knife/Multiple_Other : 2450 png files, 2450 anno files, same size
# ./Train/Smith/Knife/Single_Default : 1224 png files, 1224 anno files, same size
# ./Train/Smith/Knife/Single_Other : 1225 png files, 1225 anno files, same size
# ====================================================================================================
# ./Train/Smith/LapTop/Multiple_Categories : 1340 png files, 1340 anno files, same size
# ./Train/Smith/LapTop/Multiple_Other : 1000 png files, 1000 anno files, same size
# ./Train/Smith/LapTop/Single_Default : 500 png files, 500 anno files, same size
# ./Train/Smith/LapTop/Single_Other : 500 png files, 500 anno files, same size
# ====================================================================================================
# ./Train/Smith/Lighter/Multiple_Categories : 2675 png files, 2675 anno files, same size
# ./Train/Smith/Lighter/Multiple_Other : 2000 png files, 2000 anno files, same size
# ./Train/Smith/Lighter/Single_Default : 1000 png files, 1000 anno files, same size
# ./Train/Smith/Lighter/Single_Other : 1000 png files, 1000 anno files, same size
# ====================================================================================================
# ./Train/Smith/Liquid/Multiple_Categories : 1675 png files, 1675 anno files, same size
# ./Train/Smith/Liquid/Multiple_Other : 1250 png files, 1250 anno files, same size
# ./Train/Smith/Liquid/Single_Default : 625 png files, 625 anno files, same size
# ./Train/Smith/Liquid/Single_Other : 625 png files, 625 anno files, same size
# ====================================================================================================
# ./Train/Smith/Match/Multiple_Categories : 670 png files, 670 anno files, same size
# ./Train/Smith/Match/Multiple_Other : 500 png files, 500 anno files, same size
# ./Train/Smith/Match/Single_Default : 250 png files, 250 anno files, same size
# ./Train/Smith/Match/Single_Other : 250 png files, 250 anno files, same size
# ====================================================================================================
# ./Train/Smith/MetalPipe/Multiple_Categories : 1675 png files, 1675 anno files, same size
# ./Train/Smith/MetalPipe/Multiple_Other : 1250 png files, 1250 anno files, same size
# ./Train/Smith/MetalPipe/Single_Default : 625 png files, 625 anno files, same size
# ./Train/Smith/MetalPipe/Single_Other : 625 png files, 625 anno files, same size
# ====================================================================================================
# ./Train/Smith/NailClippers/Multiple_Categories : 1340 png files, 1340 anno files, same size
# ./Train/Smith/NailClippers/Multiple_Other : 1000 png files, 1000 anno files, same size
# ./Train/Smith/NailClippers/Single_Default : 500 png files, 500 anno files, same size
# ./Train/Smith/NailClippers/Single_Other : 500 png files, 500 anno files, same size
# ====================================================================================================
# ./Train/Smith/Plier/Multiple_Categories : 1340 png files, 1340 anno files, same size
# ./Train/Smith/Plier/Multiple_Other : 1000 png files, 1000 anno files, same size
# ./Train/Smith/Plier/Single_Default : 500 png files, 500 anno files, same size
# ./Train/Smith/Plier/Single_Other : 500 png files, 500 anno files, same size
# ====================================================================================================
# ./Train/Smith/PortableGas/Multiple_Categories : 930 png files, 930 anno files, same size
# ./Train/Smith/PortableGas/Multiple_Other : 700 png files, 700 anno files, same size
# ./Train/Smith/PortableGas/Single_Default : 350 png files, 350 anno files, same size
# ./Train/Smith/PortableGas/Single_Other : 350 png files, 350 anno files, same size
# ====================================================================================================
# ./Train/Smith/Saw/Multiple_Categories : 3255 png files, 3255 anno files, same size
# ./Train/Smith/Saw/Multiple_Other : 2450 png files, 2450 anno files, same size
# ./Train/Smith/Saw/Single_Default : 1225 png files, 1225 anno files, same size
# ./Train/Smith/Saw/Single_Other : 1225 png files, 1225 anno files, same size
# ====================================================================================================
# ./Train/Smith/Scissors/Multiple_Categories : 3255 png files, 3255 anno files, same size
# ./Train/Smith/Scissors/Multiple_Other : 2450 png files, 2450 anno files, same size
# ./Train/Smith/Scissors/Single_Default : 1225 png files, 1225 anno files, same size
# ./Train/Smith/Scissors/Single_Other : 1225 png files, 1225 anno files, same size
# ====================================================================================================
# ./Train/Smith/Screwdriver/Multiple_Categories : 2000 png files, 2000 anno files, same size
# ./Train/Smith/Screwdriver/Multiple_Other : 1500 png files, 1500 anno files, same size
# ./Train/Smith/Screwdriver/Single_Default : 750 png files, 750 anno files, same size
# ./Train/Smith/Screwdriver/Single_Other : 540 png files, 540 anno files, same size
# ====================================================================================================
# ./Train/Smith/SmartPhone/Multiple_Categories : 1005 png files, 1076 anno files, same size
# ./Train/Smith/SmartPhone/Multiple_Other : 823 png files, 823 anno files, same size
# ./Train/Smith/SmartPhone/Single_Default : 375 png files, 449 anno files, same size
# ./Train/Smith/SmartPhone/Single_Other : 375 png files, 452 anno files, same size
# ====================================================================================================
# ./Train/Smith/SolidFuel/Multiple_Categories : 670 png files, 670 anno files, same size
# ./Train/Smith/SolidFuel/Multiple_Other : 500 png files, 500 anno files, same size
# ./Train/Smith/SolidFuel/Single_Default : 250 png files, 250 anno files, same size
# ./Train/Smith/SolidFuel/Single_Other : 250 png files, 250 anno files, same size
# ====================================================================================================
# ./Train/Smith/Spanner/Multiple_Categories : 2000 png files, 2000 anno files, same size
# ./Train/Smith/Spanner/Multiple_Other : 1500 png files, 1500 anno files, same size
# ./Train/Smith/Spanner/Single_Default : 749 png files, 749 anno files, same size
# ./Train/Smith/Spanner/Single_Other : 750 png files, 750 anno files, same size
# ====================================================================================================
# ./Train/Smith/SSD/Multiple_Categories : 670 png files, 670 anno files, same size
# ./Train/Smith/SSD/Multiple_Other : 500 png files, 500 anno files, same size
# ./Train/Smith/SSD/Single_Default : 245 png files, 245 anno files, same size
# ./Train/Smith/SSD/Single_Other : 250 png files, 250 anno files, same size
# ====================================================================================================
# ./Train/Smith/SupplymentaryBattery/Multiple_Categories : 2010 png files, 2010 anno files, same size
# ./Train/Smith/SupplymentaryBattery/Multiple_Other : 1500 png files, 1500 anno files, same size
# ./Train/Smith/SupplymentaryBattery/Single_Default : 750 png files, 750 anno files, same size
# ./Train/Smith/SupplymentaryBattery/Single_Other : 750 png files, 750 anno files, same size
# ====================================================================================================
# ./Train/Smith/TabletPC/Multiple_Categories : 670 png files, 702 anno files, same size
# ./Train/Smith/TabletPC/Multiple_Other : 544 png files, 544 anno files, same size
# ./Train/Smith/TabletPC/Single_Default : 250 png files, 301 anno files, same size
# ./Train/Smith/TabletPC/Single_Other : 250 png files, 302 anno files, same size
# ====================================================================================================
# ./Train/Smith/Thinner/Multiple_Categories : 335 png files, 335 anno files, same size
# ./Train/Smith/Thinner/Multiple_Other : 250 png files, 250 anno files, same size
# ./Train/Smith/Thinner/Single_Default : 125 png files, 125 anno files, same size
# ./Train/Smith/Thinner/Single_Other : 125 png files, 125 anno files, same size
# ====================================================================================================
# ./Train/Smith/ThrowingKnife/Multiple_Categories : 335 png files, 335 anno files, same size
# ./Train/Smith/ThrowingKnife/Multiple_Other : 250 png files, 250 anno files, same size
# ./Train/Smith/ThrowingKnife/Single_Default : 125 png files, 125 anno files, same size
# ./Train/Smith/ThrowingKnife/Single_Other : 125 png files, 125 anno files, same size
# ====================================================================================================
# ./Train/Smith/USB/Multiple_Categories : 1340 png files, 1340 anno files, same size
# ./Train/Smith/USB/Multiple_Other : 1000 png files, 1000 anno files, same size
# ./Train/Smith/USB/Single_Default : 500 png files, 500 anno files, same size
# ./Train/Smith/USB/Single_Other : 500 png files, 500 anno files, same size
# ====================================================================================================
# ./Train/Smith/ZippoOil/Multiple_Categories : 335 png files, 335 anno files, same size
# ./Train/Smith/ZippoOil/Multiple_Other : 250 png files, 250 anno files, same size
# ./Train/Smith/ZippoOil/Single_Default : 125 png files, 125 anno files, same size
# ./Train/Smith/ZippoOil/Single_Other : 125 png files, 125 anno files, same size
# ====================================================================================================
# ====================================================================================================
# ./Train/Astrophysics/Aerosol/Multiple_Categories : 930 png files, 930 anno files, same size
# ./Train/Astrophysics/Aerosol/Multiple_Other : 700 png files, 700 anno files, same size
# ./Train/Astrophysics/Aerosol/Single_Default : 350 png files, 350 anno files, same size
# ./Train/Astrophysics/Aerosol/Single_Other : 350 png files, 350 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/Alcohol/Multiple_Categories : 335 png files, 335 anno files, same size
# ./Train/Astrophysics/Alcohol/Multiple_Other : 250 png files, 250 anno files, same size
# ./Train/Astrophysics/Alcohol/Single_Default : 125 png files, 125 anno files, same size
# ./Train/Astrophysics/Alcohol/Single_Other : 125 png files, 125 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/Awl/Multiple_Categories : 1860 png files, 1860 anno files, same size
# ./Train/Astrophysics/Awl/Multiple_Other : 1400 png files, 1400 anno files, same size
# ./Train/Astrophysics/Awl/Single_Default : 700 png files, 700 anno files, same size
# ./Train/Astrophysics/Awl/Single_Other : 700 png files, 700 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/Axe/Multiple_Categories : 2140 png files, 2140 anno files, same size
# ./Train/Astrophysics/Axe/Multiple_Other : 1600 png files, 1600 anno files, same size
# ./Train/Astrophysics/Axe/Single_Default : 800 png files, 800 anno files, same size
# ./Train/Astrophysics/Axe/Single_Other : 800 png files, 800 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/Bat/Multiple_Categories : 670 png files, 670 anno files, same size
# ./Train/Astrophysics/Bat/Multiple_Other : 500 png files, 500 anno files, same size
# ./Train/Astrophysics/Bat/Single_Default : 250 png files, 250 anno files, same size
# ./Train/Astrophysics/Bat/Single_Other : 250 png files, 250 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/Battery/Multiple_Categories : 335 png files, 335 anno files, same size
# ./Train/Astrophysics/Battery/Multiple_Other : 250 png files, 250 anno files, same size
# ./Train/Astrophysics/Battery/Single_Default : 125 png files, 125 anno files, same size
# ./Train/Astrophysics/Battery/Single_Other : 125 png files, 125 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/Bullet/Multiple_Categories : 1605 png files, 1605 anno files, same size
# ./Train/Astrophysics/Bullet/Multiple_Other : 1200 png files, 1200 anno files, same size
# ./Train/Astrophysics/Bullet/Single_Default : 600 png files, 600 anno files, same size
# ./Train/Astrophysics/Bullet/Single_Other : 600 png files, 600 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/Chisel/Multiple_Categories : 2325 png files, 2325 anno files, same size
# ./Train/Astrophysics/Chisel/Multiple_Other : 1750 png files, 1750 anno files, same size
# ./Train/Astrophysics/Chisel/Single_Default : 875 png files, 875 anno files, same size
# ./Train/Astrophysics/Chisel/Single_Other : 875 png files, 875 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/ElectronicCigarettes/Multiple_Categories : 670 png files, 670 anno files, same size
# ./Train/Astrophysics/ElectronicCigarettes/Multiple_Other : 498 png files, 498 anno files, same size
# ./Train/Astrophysics/ElectronicCigarettes/Single_Default : 250 png files, 250 anno files, same size
# ./Train/Astrophysics/ElectronicCigarettes/Single_Other : 250 png files, 250 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/ElectronicCigarettesLiquid/Multiple_Categories : 670 png files, 670 anno files, same size
# ./Train/Astrophysics/ElectronicCigarettesLiquid/Multiple_Other : 500 png files, 500 anno files, same size
# ./Train/Astrophysics/ElectronicCigarettesLiquid/Single_Default : 250 png files, 250 anno files, same size
# ./Train/Astrophysics/ElectronicCigarettesLiquid/Single_Other : 250 png files, 250 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/Firecracker/Multiple_Categories : 2675 png files, 2675 anno files, same size
# ./Train/Astrophysics/Firecracker/Multiple_Other : 2000 png files, 2000 anno files, same size
# ./Train/Astrophysics/Firecracker/Single_Default : 1000 png files, 1000 anno files, same size
# ./Train/Astrophysics/Firecracker/Single_Other : 1000 png files, 1000 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/Gun/Multiple_Categories : 2140 png files, 2140 anno files, same size
# ./Train/Astrophysics/Gun/Multiple_Other : 1600 png files, 1600 anno files, same size
# ./Train/Astrophysics/Gun/Single_Default : 800 png files, 800 anno files, same size
# ./Train/Astrophysics/Gun/Single_Other : 800 png files, 800 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/GunParts/Multiple_Categories : 2675 png files, 2675 anno files, same size
# ./Train/Astrophysics/GunParts/Multiple_Other : 2000 png files, 2000 anno files, same size
# ./Train/Astrophysics/GunParts/Single_Default : 1000 png files, 1000 anno files, same size
# ./Train/Astrophysics/GunParts/Single_Other : 1000 png files, 1000 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/Hammer/Multiple_Categories : 2140 png files, 2140 anno files, same size
# ./Train/Astrophysics/Hammer/Multiple_Other : 1600 png files, 1600 anno files, same size
# ./Train/Astrophysics/Hammer/Single_Default : 800 png files, 800 anno files, same size
# ./Train/Astrophysics/Hammer/Single_Other : 800 png files, 800 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/HandCuffs/Multiple_Categories : 335 png files, 335 anno files, same size
# ./Train/Astrophysics/HandCuffs/Multiple_Other : 250 png files, 250 anno files, same size
# ./Train/Astrophysics/HandCuffs/Single_Default : 125 png files, 125 anno files, same size
# ./Train/Astrophysics/HandCuffs/Single_Other : 125 png files, 125 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/HDDExternal/Multiple_Categories : 335 png files, 389 anno files, same size
# ./Train/Astrophysics/HDDExternal/Multiple_Other : 318 png files, 318 anno files, same size
# ./Train/Astrophysics/HDDExternal/Single_Default : 125 png files, 162 anno files, same size
# ./Train/Astrophysics/HDDExternal/Single_Other : 125 png files, 158 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/HDD/Multiple_Categories : 335 png files, 335 anno files, same size
# ./Train/Astrophysics/HDD/Multiple_Other : 250 png files, 250 anno files, same size
# ./Train/Astrophysics/HDD/Single_Default : 125 png files, 125 anno files, same size
# ./Train/Astrophysics/HDD/Single_Other : 125 png files, 125 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/Knife/Multiple_Categories : 3255 png files, 3255 anno files, same size
# ./Train/Astrophysics/Knife/Multiple_Other : 2450 png files, 2450 anno files, same size
# ./Train/Astrophysics/Knife/Single_Default : 1225 png files, 1225 anno files, same size
# ./Train/Astrophysics/Knife/Single_Other : 1225 png files, 1225 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/LapTop/Multiple_Categories : 1339 png files, 1339 anno files, same size
# ./Train/Astrophysics/LapTop/Multiple_Other : 1000 png files, 1000 anno files, same size
# ./Train/Astrophysics/LapTop/Single_Default : 500 png files, 500 anno files, same size
# ./Train/Astrophysics/LapTop/Single_Other : 500 png files, 500 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/Lighter/Multiple_Categories : 2675 png files, 2675 anno files, same size
# ./Train/Astrophysics/Lighter/Multiple_Other : 2000 png files, 2000 anno files, same size
# ./Train/Astrophysics/Lighter/Single_Default : 1000 png files, 1000 anno files, same size
# ./Train/Astrophysics/Lighter/Single_Other : 1000 png files, 1000 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/Liquid/Multiple_Categories : 1675 png files, 1675 anno files, same size
# ./Train/Astrophysics/Liquid/Multiple_Other : 1250 png files, 1250 anno files, same size
# ./Train/Astrophysics/Liquid/Single_Default : 625 png files, 625 anno files, same size
# ./Train/Astrophysics/Liquid/Single_Other : 625 png files, 625 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/Match/Multiple_Categories : 670 png files, 670 anno files, same size
# ./Train/Astrophysics/Match/Multiple_Other : 500 png files, 500 anno files, same size
# ./Train/Astrophysics/Match/Single_Default : 250 png files, 250 anno files, same size
# ./Train/Astrophysics/Match/Single_Other : 250 png files, 250 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/MetalPipe/Multiple_Categories : 1675 png files, 1675 anno files, same size
# ./Train/Astrophysics/MetalPipe/Multiple_Other : 1250 png files, 1250 anno files, same size
# ./Train/Astrophysics/MetalPipe/Single_Default : 625 png files, 625 anno files, same size
# ./Train/Astrophysics/MetalPipe/Single_Other : 625 png files, 625 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/NailClippers/Multiple_Categories : 1340 png files, 1340 anno files, same size
# ./Train/Astrophysics/NailClippers/Multiple_Other : 1000 png files, 1000 anno files, same size
# ./Train/Astrophysics/NailClippers/Single_Default : 500 png files, 500 anno files, same size
# ./Train/Astrophysics/NailClippers/Single_Other : 500 png files, 500 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/Plier/Multiple_Categories : 1340 png files, 1340 anno files, same size
# ./Train/Astrophysics/Plier/Multiple_Other : 1000 png files, 1000 anno files, same size
# ./Train/Astrophysics/Plier/Single_Default : 500 png files, 500 anno files, same size
# ./Train/Astrophysics/Plier/Single_Other : 500 png files, 500 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/PortableGas/Multiple_Categories : 930 png files, 930 anno files, same size
# ./Train/Astrophysics/PortableGas/Multiple_Other : 700 png files, 700 anno files, same size
# ./Train/Astrophysics/PortableGas/Single_Default : 350 png files, 350 anno files, same size
# ./Train/Astrophysics/PortableGas/Single_Other : 350 png files, 350 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/Saw/Multiple_Categories : 3255 png files, 3255 anno files, same size
# ./Train/Astrophysics/Saw/Multiple_Other : 2450 png files, 2450 anno files, same size
# ./Train/Astrophysics/Saw/Single_Default : 1225 png files, 1225 anno files, same size
# ./Train/Astrophysics/Saw/Single_Other : 1225 png files, 1225 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/Scissors/Multiple_Categories : 3255 png files, 3255 anno files, same size
# ./Train/Astrophysics/Scissors/Multiple_Other : 2450 png files, 2450 anno files, same size
# ./Train/Astrophysics/Scissors/Single_Default : 1225 png files, 1225 anno files, same size
# ./Train/Astrophysics/Scissors/Single_Other : 1225 png files, 1225 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/Screwdriver/Multiple_Categories : 2000 png files, 2000 anno files, same size
# ./Train/Astrophysics/Screwdriver/Multiple_Other : 1500 png files, 1500 anno files, same size
# ./Train/Astrophysics/Screwdriver/Single_Default : 750 png files, 750 anno files, same size
# ./Train/Astrophysics/Screwdriver/Single_Other : 750 png files, 750 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/SmartPhone/Multiple_Categories : 1005 png files, 1005 anno files, same size
# ./Train/Astrophysics/SmartPhone/Multiple_Other : 750 png files, 750 anno files, same size
# ./Train/Astrophysics/SmartPhone/Single_Default : 375 png files, 375 anno files, same size
# ./Train/Astrophysics/SmartPhone/Single_Other : 375 png files, 375 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/SolidFuel/Multiple_Categories : 670 png files, 670 anno files, same size
# ./Train/Astrophysics/SolidFuel/Multiple_Other : 500 png files, 500 anno files, same size
# ./Train/Astrophysics/SolidFuel/Single_Default : 250 png files, 250 anno files, same size
# ./Train/Astrophysics/SolidFuel/Single_Other : 250 png files, 250 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/Spanner/Multiple_Categories : 2000 png files, 2000 anno files, same size
# ./Train/Astrophysics/Spanner/Multiple_Other : 1500 png files, 1500 anno files, same size
# ./Train/Astrophysics/Spanner/Single_Default : 750 png files, 750 anno files, same size
# ./Train/Astrophysics/Spanner/Single_Other : 750 png files, 750 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/SSD/Multiple_Categories : 668 png files, 668 anno files, same size
# ./Train/Astrophysics/SSD/Multiple_Other : 500 png files, 500 anno files, same size
# ./Train/Astrophysics/SSD/Single_Default : 250 png files, 250 anno files, same size
# ./Train/Astrophysics/SSD/Single_Other : 250 png files, 250 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/SupplymentaryBattery/Multiple_Categories : 2009 png files, 2009 anno files, same size
# ./Train/Astrophysics/SupplymentaryBattery/Multiple_Other : 1500 png files, 1500 anno files, same size
# ./Train/Astrophysics/SupplymentaryBattery/Single_Default : 750 png files, 750 anno files, same size
# ./Train/Astrophysics/SupplymentaryBattery/Single_Other : 750 png files, 750 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/TabletPC/Multiple_Categories : 670 png files, 713 anno files, same size
# ./Train/Astrophysics/TabletPC/Multiple_Other : 598 png files, 598 anno files, same size
# ./Train/Astrophysics/TabletPC/Single_Default : 250 png files, 307 anno files, same size
# ./Train/Astrophysics/TabletPC/Single_Other : 250 png files, 319 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/Thinner/Multiple_Categories : 335 png files, 335 anno files, same size
# ./Train/Astrophysics/Thinner/Multiple_Other : 250 png files, 250 anno files, same size
# ./Train/Astrophysics/Thinner/Single_Default : 125 png files, 125 anno files, same size
# ./Train/Astrophysics/Thinner/Single_Other : 125 png files, 125 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/ThrowingKnife/Multiple_Categories : 335 png files, 335 anno files, same size
# ./Train/Astrophysics/ThrowingKnife/Multiple_Other : 250 png files, 250 anno files, same size
# ./Train/Astrophysics/ThrowingKnife/Single_Default : 125 png files, 125 anno files, same size
# ./Train/Astrophysics/ThrowingKnife/Single_Other : 125 png files, 125 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/USB/Multiple_Categories : 1340 png files, 1340 anno files, same size
# ./Train/Astrophysics/USB/Multiple_Other : 1000 png files, 1000 anno files, same size
# ./Train/Astrophysics/USB/Single_Default : 500 png files, 500 anno files, same size
# ./Train/Astrophysics/USB/Single_Other : 500 png files, 500 anno files, same size
# ====================================================================================================
# ./Train/Astrophysics/ZippoOil/Multiple_Categories : 335 png files, 335 anno files, same size
# ./Train/Astrophysics/ZippoOil/Multiple_Other : 250 png files, 250 anno files, same size
# ./Train/Astrophysics/ZippoOil/Single_Default : 125 png files, 125 anno files, same size
# ./Train/Astrophysics/ZippoOil/Single_Other : 125 png files, 125 anno files, same size
# ====================================================================================================
# ====================================================================================================
# ./Train/Rapiscan/Aerosol/Multiple_Categories : 929 png files, 929 anno files, same size
# ./Train/Rapiscan/Aerosol/Multiple_Other : 700 png files, 700 anno files, same size
# ./Train/Rapiscan/Aerosol/Single_Default : 350 png files, 350 anno files, same size
# ./Train/Rapiscan/Aerosol/Single_Other : 350 png files, 350 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/Alcohol/Multiple_Categories : 335 png files, 335 anno files, same size
# ./Train/Rapiscan/Alcohol/Multiple_Other : 250 png files, 250 anno files, same size
# ./Train/Rapiscan/Alcohol/Single_Default : 125 png files, 125 anno files, same size
# ./Train/Rapiscan/Alcohol/Single_Other : 125 png files, 125 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/Awl/Multiple_Categories : 1860 png files, 1860 anno files, same size
# ./Train/Rapiscan/Awl/Multiple_Other : 1400 png files, 1400 anno files, same size
# ./Train/Rapiscan/Awl/Single_Default : 700 png files, 700 anno files, same size
# ./Train/Rapiscan/Awl/Single_Other : 700 png files, 700 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/Axe/Multiple_Categories : 2139 png files, 2139 anno files, same size
# ./Train/Rapiscan/Axe/Multiple_Other : 1600 png files, 1600 anno files, same size
# ./Train/Rapiscan/Axe/Single_Default : 800 png files, 800 anno files, same size
# ./Train/Rapiscan/Axe/Single_Other : 800 png files, 800 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/Bat/Multiple_Categories : 670 png files, 670 anno files, same size
# ./Train/Rapiscan/Bat/Multiple_Other : 500 png files, 500 anno files, same size
# ./Train/Rapiscan/Bat/Single_Default : 250 png files, 250 anno files, same size
# ./Train/Rapiscan/Bat/Single_Other : 250 png files, 250 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/Battery/Multiple_Categories : 335 png files, 335 anno files, same size
# ./Train/Rapiscan/Battery/Multiple_Other : 250 png files, 250 anno files, same size
# ./Train/Rapiscan/Battery/Single_Default : 125 png files, 125 anno files, same size
# ./Train/Rapiscan/Battery/Single_Other : 125 png files, 125 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/Bullet/Multiple_Categories : 1605 png files, 1605 anno files, same size
# ./Train/Rapiscan/Bullet/Multiple_Other : 1200 png files, 1200 anno files, same size
# ./Train/Rapiscan/Bullet/Single_Default : 600 png files, 600 anno files, same size
# ./Train/Rapiscan/Bullet/Single_Other : 600 png files, 600 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/Chisel/Multiple_Categories : 2325 png files, 2325 anno files, same size
# ./Train/Rapiscan/Chisel/Multiple_Other : 1750 png files, 1750 anno files, same size
# ./Train/Rapiscan/Chisel/Single_Default : 875 png files, 875 anno files, same size
# ./Train/Rapiscan/Chisel/Single_Other : 875 png files, 875 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/ElectronicCigarettes/Multiple_Categories : 670 png files, 670 anno files, same size
# ./Train/Rapiscan/ElectronicCigarettes/Multiple_Other : 500 png files, 500 anno files, same size
# ./Train/Rapiscan/ElectronicCigarettes/Single_Default : 250 png files, 250 anno files, same size
# ./Train/Rapiscan/ElectronicCigarettes/Single_Other : 250 png files, 250 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/ElectronicCigarettesLiquid/Multiple_Categories : 670 png files, 670 anno files, same size
# ./Train/Rapiscan/ElectronicCigarettesLiquid/Multiple_Other : 500 png files, 500 anno files, same size
# ./Train/Rapiscan/ElectronicCigarettesLiquid/Single_Default : 250 png files, 250 anno files, same size
# ./Train/Rapiscan/ElectronicCigarettesLiquid/Single_Other : 250 png files, 250 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/Firecracker/Multiple_Categories : 2675 png files, 2675 anno files, same size
# ./Train/Rapiscan/Firecracker/Multiple_Other : 2000 png files, 2000 anno files, same size
# ./Train/Rapiscan/Firecracker/Single_Default : 1000 png files, 1000 anno files, same size
# ./Train/Rapiscan/Firecracker/Single_Other : 1000 png files, 1000 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/Gun/Multiple_Categories : 2140 png files, 2140 anno files, same size
# ./Train/Rapiscan/Gun/Multiple_Other : 1600 png files, 1600 anno files, same size
# ./Train/Rapiscan/Gun/Single_Default : 800 png files, 800 anno files, same size
# ./Train/Rapiscan/Gun/Single_Other : 800 png files, 800 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/GunParts/Multiple_Categories : 2675 png files, 2675 anno files, same size
# ./Train/Rapiscan/GunParts/Multiple_Other : 2000 png files, 2000 anno files, same size
# ./Train/Rapiscan/GunParts/Single_Default : 1000 png files, 1000 anno files, same size
# ./Train/Rapiscan/GunParts/Single_Other : 1000 png files, 1000 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/Hammer/Multiple_Categories : 2140 png files, 2140 anno files, same size
# ./Train/Rapiscan/Hammer/Multiple_Other : 1600 png files, 1600 anno files, same size
# ./Train/Rapiscan/Hammer/Single_Default : 800 png files, 800 anno files, same size
# ./Train/Rapiscan/Hammer/Single_Other : 800 png files, 800 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/HandCuffs/Multiple_Categories : 335 png files, 335 anno files, same size
# ./Train/Rapiscan/HandCuffs/Multiple_Other : 250 png files, 250 anno files, same size
# ./Train/Rapiscan/HandCuffs/Single_Default : 125 png files, 125 anno files, same size
# ./Train/Rapiscan/HandCuffs/Single_Other : 125 png files, 125 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/HDDExternal/Multiple_Categories : 335 png files, 355 anno files, same size
# ./Train/Rapiscan/HDDExternal/Multiple_Other : 271 png files, 271 anno files, same size
# ./Train/Rapiscan/HDDExternal/Single_Default : 125 png files, 153 anno files, same size
# ./Train/Rapiscan/HDDExternal/Single_Other : 125 png files, 142 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/HDD/Multiple_Categories : 335 png files, 335 anno files, same size
# ./Train/Rapiscan/HDD/Multiple_Other : 250 png files, 250 anno files, same size
# ./Train/Rapiscan/HDD/Single_Default : 125 png files, 125 anno files, same size
# ./Train/Rapiscan/HDD/Single_Other : 125 png files, 125 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/Knife/Multiple_Categories : 3254 png files, 3254 anno files, same size
# ./Train/Rapiscan/Knife/Multiple_Other : 2448 png files, 2448 anno files, same size
# ./Train/Rapiscan/Knife/Single_Default : 1225 png files, 1225 anno files, same size
# ./Train/Rapiscan/Knife/Single_Other : 1225 png files, 1225 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/LapTop/Multiple_Categories : 1340 png files, 1451 anno files, same size
# ./Train/Rapiscan/LapTop/Multiple_Other : 1128 png files, 1128 anno files, same size
# ./Train/Rapiscan/LapTop/Single_Default : 500 png files, 500 anno files, same size
# ./Train/Rapiscan/LapTop/Single_Other : 500 png files, 500 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/Lighter/Multiple_Categories : 2675 png files, 2675 anno files, same size
# ./Train/Rapiscan/Lighter/Multiple_Other : 2000 png files, 2000 anno files, same size
# ./Train/Rapiscan/Lighter/Single_Default : 1000 png files, 1000 anno files, same size
# ./Train/Rapiscan/Lighter/Single_Other : 1000 png files, 1000 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/Liquid/Multiple_Categories : 1675 png files, 1675 anno files, same size
# ./Train/Rapiscan/Liquid/Multiple_Other : 1250 png files, 1250 anno files, same size
# ./Train/Rapiscan/Liquid/Single_Default : 625 png files, 625 anno files, same size
# ./Train/Rapiscan/Liquid/Single_Other : 625 png files, 625 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/Match/Multiple_Categories : 670 png files, 670 anno files, same size
# ./Train/Rapiscan/Match/Multiple_Other : 500 png files, 500 anno files, same size
# ./Train/Rapiscan/Match/Single_Default : 250 png files, 250 anno files, same size
# ./Train/Rapiscan/Match/Single_Other : 250 png files, 250 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/MetalPipe/Multiple_Categories : 1675 png files, 1675 anno files, same size
# ./Train/Rapiscan/MetalPipe/Multiple_Other : 1250 png files, 1250 anno files, same size
# ./Train/Rapiscan/MetalPipe/Single_Default : 625 png files, 625 anno files, same size
# ./Train/Rapiscan/MetalPipe/Single_Other : 625 png files, 625 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/NailClippers/Multiple_Categories : 1340 png files, 1340 anno files, same size
# ./Train/Rapiscan/NailClippers/Multiple_Other : 1000 png files, 1000 anno files, same size
# ./Train/Rapiscan/NailClippers/Single_Default : 500 png files, 500 anno files, same size
# ./Train/Rapiscan/NailClippers/Single_Other : 500 png files, 500 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/Plier/Multiple_Categories : 1340 png files, 1340 anno files, same size
# ./Train/Rapiscan/Plier/Multiple_Other : 1000 png files, 1000 anno files, same size
# ./Train/Rapiscan/Plier/Single_Default : 500 png files, 500 anno files, same size
# ./Train/Rapiscan/Plier/Single_Other : 500 png files, 500 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/PortableGas/Multiple_Categories : 930 png files, 930 anno files, same size
# ./Train/Rapiscan/PortableGas/Multiple_Other : 700 png files, 700 anno files, same size
# ./Train/Rapiscan/PortableGas/Single_Default : 350 png files, 350 anno files, same size
# ./Train/Rapiscan/PortableGas/Single_Other : 350 png files, 350 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/Saw/Multiple_Categories : 3255 png files, 3255 anno files, same size
# ./Train/Rapiscan/Saw/Multiple_Other : 2450 png files, 2450 anno files, same size
# ./Train/Rapiscan/Saw/Single_Default : 1225 png files, 1225 anno files, same size
# ./Train/Rapiscan/Saw/Single_Other : 1225 png files, 1225 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/Scissors/Multiple_Categories : 3251 png files, 3251 anno files, same size
# ./Train/Rapiscan/Scissors/Multiple_Other : 2450 png files, 2450 anno files, same size
# ./Train/Rapiscan/Scissors/Single_Default : 1225 png files, 1225 anno files, same size
# ./Train/Rapiscan/Scissors/Single_Other : 1225 png files, 1225 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/Screwdriver/Multiple_Categories : 2000 png files, 2000 anno files, same size
# ./Train/Rapiscan/Screwdriver/Multiple_Other : 1500 png files, 1500 anno files, same size
# ./Train/Rapiscan/Screwdriver/Single_Default : 750 png files, 750 anno files, same size
# ./Train/Rapiscan/Screwdriver/Single_Other : 750 png files, 750 anno files, same size
# ====================================================================================================
# ./Train/Rapiscan/SmartPhone/Multiple_Categories : 1005 png files, 1005 anno files, same size
# ./Train/Rapiscan/SmartPhone/Multiple_Other : 750 png files, 750 anno files, same size
# ...
# ./Validation/Rapiscan/Bat/Single_Default : 30 png files, 30 anno files, same size
# ./Validation/Rapiscan/Bat/Single_Other : 30 png files, 30 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/Battery/Multiple_Categories : 25 png files, 25 anno files, same size
# ./Validation/Rapiscan/Battery/Multiple_Other : 30 png files, 30 anno files, same size
# ./Validation/Rapiscan/Battery/Single_Default : 25 png files, 25 anno files, same size
# ./Validation/Rapiscan/Battery/Single_Other : 25 png files, 25 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/Bullet/Multiple_Categories : 75 png files, 75 anno files, same size
# ./Validation/Rapiscan/Bullet/Multiple_Other : 60 png files, 60 anno files, same size
# ./Validation/Rapiscan/Bullet/Single_Default : 60 png files, 60 anno files, same size
# ./Validation/Rapiscan/Bullet/Single_Other : 60 png files, 60 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/Chisel/Multiple_Categories : 175 png files, 175 anno files, same size
# ./Validation/Rapiscan/Chisel/Multiple_Other : 150 png files, 150 anno files, same size
# ./Validation/Rapiscan/Chisel/Single_Default : 137 png files, 137 anno files, same size
# ./Validation/Rapiscan/Chisel/Single_Other : 127 png files, 127 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/ElectronicCigarettes/Multiple_Categories : 50 png files, 50 anno files, same size
# ./Validation/Rapiscan/ElectronicCigarettes/Multiple_Other : 60 png files, 60 anno files, same size
# ./Validation/Rapiscan/ElectronicCigarettes/Single_Default : 30 png files, 30 anno files, same size
# ./Validation/Rapiscan/ElectronicCigarettes/Single_Other : 30 png files, 30 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/ElectronicCigarettesLiquid/Multiple_Categories : 50 png files, 50 anno files, same size
# ./Validation/Rapiscan/ElectronicCigarettesLiquid/Multiple_Other : 60 png files, 60 anno files, same size
# ./Validation/Rapiscan/ElectronicCigarettesLiquid/Single_Default : 30 png files, 30 anno files, same size
# ./Validation/Rapiscan/ElectronicCigarettesLiquid/Single_Other : 30 png files, 30 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/Firecracker/Multiple_Categories : 169 png files, 169 anno files, same size
# ./Validation/Rapiscan/Firecracker/Multiple_Other : 144 png files, 144 anno files, same size
# ./Validation/Rapiscan/Firecracker/Single_Default : 102 png files, 102 anno files, same size
# ./Validation/Rapiscan/Firecracker/Single_Other : 104 png files, 104 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/Gun/Multiple_Categories : 124 png files, 124 anno files, same size
# ./Validation/Rapiscan/Gun/Multiple_Other : 102 png files, 102 anno files, same size
# ./Validation/Rapiscan/Gun/Single_Default : 80 png files, 80 anno files, same size
# ./Validation/Rapiscan/Gun/Single_Other : 86 png files, 86 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/GunParts/Multiple_Categories : 125 png files, 125 anno files, same size
# ./Validation/Rapiscan/GunParts/Multiple_Other : 100 png files, 100 anno files, same size
# ./Validation/Rapiscan/GunParts/Single_Default : 100 png files, 100 anno files, same size
# ./Validation/Rapiscan/GunParts/Single_Other : 100 png files, 100 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/Hammer/Multiple_Categories : 2428 png files, 2428 anno files, same size
# ./Validation/Rapiscan/Hammer/Multiple_Other : 1864 png files, 1864 anno files, same size
# ./Validation/Rapiscan/Hammer/Single_Default : 976 png files, 976 anno files, same size
# ./Validation/Rapiscan/Hammer/Single_Other : 976 png files, 976 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/HandCuffs/Multiple_Categories : 25 png files, 25 anno files, same size
# ./Validation/Rapiscan/HandCuffs/Multiple_Other : 30 png files, 30 anno files, same size
# ./Validation/Rapiscan/HandCuffs/Single_Default : 15 png files, 15 anno files, same size
# ./Validation/Rapiscan/HandCuffs/Single_Other : 15 png files, 15 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/HDDExternal/Multiple_Categories : 20 png files, 20 anno files, same size
# ./Validation/Rapiscan/HDDExternal/Multiple_Other : 0 png files, 0 anno files, same size
# ./Validation/Rapiscan/HDDExternal/Single_Default : 28 png files, 28 anno files, same size
# ./Validation/Rapiscan/HDDExternal/Single_Other : 17 png files, 17 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/HDD/Multiple_Categories : 27 png files, 27 anno files, same size
# ./Validation/Rapiscan/HDD/Multiple_Other : 27 png files, 27 anno files, same size
# ./Validation/Rapiscan/HDD/Single_Default : 17 png files, 17 anno files, same size
# ./Validation/Rapiscan/HDD/Single_Other : 18 png files, 18 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/Knife/Multiple_Categories : 2007 png files, 2007 anno files, same size
# ./Validation/Rapiscan/Knife/Multiple_Other : 1470 png files, 1470 anno files, same size
# ./Validation/Rapiscan/Knife/Single_Default : 1535 png files, 1535 anno files, same size
# ./Validation/Rapiscan/Knife/Single_Other : 883 png files, 883 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/LapTop/Multiple_Categories : 111 png files, 111 anno files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/LapTop/Multiple_Other is not exist...
# ./Validation/Rapiscan/LapTop/Single_Default : 70 png files, 70 anno files, same size
# ./Validation/Rapiscan/LapTop/Single_Other : 72 png files, 72 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/Lighter/Multiple_Categories : 141 png files, 141 anno files, same size
# ./Validation/Rapiscan/Lighter/Multiple_Other : 108 png files, 108 anno files, same size
# ./Validation/Rapiscan/Lighter/Single_Default : 718 png files, 718 anno files, same size
# ./Validation/Rapiscan/Lighter/Single_Other : 710 png files, 710 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/Liquid/Multiple_Categories : 127 png files, 127 anno files, same size
# ./Validation/Rapiscan/Liquid/Multiple_Other : 98 png files, 98 anno files, same size
# ./Validation/Rapiscan/Liquid/Single_Default : 341 png files, 341 anno files, same size
# ./Validation/Rapiscan/Liquid/Single_Other : 345 png files, 345 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/Match/Multiple_Categories : 50 png files, 50 anno files, same size
# ./Validation/Rapiscan/Match/Multiple_Other : 60 png files, 60 anno files, same size
# ./Validation/Rapiscan/Match/Single_Default : 30 png files, 30 anno files, same size
# ./Validation/Rapiscan/Match/Single_Other : 30 png files, 30 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/MetalPipe/Multiple_Categories : 125 png files, 125 anno files, same size
# ./Validation/Rapiscan/MetalPipe/Multiple_Other : 136 png files, 136 anno files, same size
# ./Validation/Rapiscan/MetalPipe/Single_Default : 75 png files, 75 anno files, same size
# ./Validation/Rapiscan/MetalPipe/Single_Other : 77 png files, 77 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/NailClippers/Multiple_Categories : 100 png files, 100 anno files, same size
# ./Validation/Rapiscan/NailClippers/Multiple_Other : 120 png files, 120 anno files, same size
# ./Validation/Rapiscan/NailClippers/Single_Default : 100 png files, 100 anno files, same size
# ./Validation/Rapiscan/NailClippers/Single_Other : 100 png files, 100 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/Plier/Multiple_Categories : 106 png files, 106 anno files, same size
# ./Validation/Rapiscan/Plier/Multiple_Other : 94 png files, 94 anno files, same size
# ./Validation/Rapiscan/Plier/Single_Default : 110 png files, 110 anno files, same size
# ./Validation/Rapiscan/Plier/Single_Other : 70 png files, 70 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/PortableGas/Multiple_Categories : 78 png files, 78 anno files, same size
# ./Validation/Rapiscan/PortableGas/Multiple_Other : 64 png files, 64 anno files, same size
# ./Validation/Rapiscan/PortableGas/Single_Default : 58 png files, 58 anno files, same size
# ./Validation/Rapiscan/PortableGas/Single_Other : 50 png files, 50 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/Saw/Multiple_Categories : 187 png files, 187 anno files, same size
# ./Validation/Rapiscan/Saw/Multiple_Other : 226 png files, 226 anno files, same size
# ./Validation/Rapiscan/Saw/Single_Default : 175 png files, 175 anno files, same size
# ./Validation/Rapiscan/Saw/Single_Other : 179 png files, 179 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/Scissors/Multiple_Categories : 221 png files, 221 anno files, same size
# ./Validation/Rapiscan/Scissors/Multiple_Other : 226 png files, 226 anno files, same size
# ./Validation/Rapiscan/Scissors/Single_Default : 185 png files, 185 anno files, same size
# ./Validation/Rapiscan/Scissors/Single_Other : 175 png files, 175 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/Screwdriver/Multiple_Categories : 100 png files, 100 anno files, same size
# ./Validation/Rapiscan/Screwdriver/Multiple_Other : 100 png files, 100 anno files, same size
# ./Validation/Rapiscan/Screwdriver/Single_Default : 270 png files, 270 anno files, same size
# ./Validation/Rapiscan/Screwdriver/Single_Other : 276 png files, 276 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/SmartPhone/Multiple_Categories : 83 png files, 83 anno files, same size
# ./Validation/Rapiscan/SmartPhone/Multiple_Other : 56 png files, 56 anno files, same size
# ./Validation/Rapiscan/SmartPhone/Single_Default : 80 png files, 80 anno files, same size
# ./Validation/Rapiscan/SmartPhone/Single_Other : 79 png files, 79 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/SolidFuel/Multiple_Categories : 50 png files, 50 anno files, same size
# ./Validation/Rapiscan/SolidFuel/Multiple_Other : 60 png files, 60 anno files, same size
# ./Validation/Rapiscan/SolidFuel/Single_Default : 30 png files, 30 anno files, same size
# ./Validation/Rapiscan/SolidFuel/Single_Other : 30 png files, 30 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/Spanner/Multiple_Categories : 108 png files, 108 anno files, same size
# ./Validation/Rapiscan/Spanner/Multiple_Other : 98 png files, 98 anno files, same size
# ./Validation/Rapiscan/Spanner/Single_Default : 340 png files, 340 anno files, same size
# ./Validation/Rapiscan/Spanner/Single_Other : 336 png files, 336 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/SSD/Multiple_Categories : 68 png files, 68 anno files, same size
# ./Validation/Rapiscan/SSD/Multiple_Other : 48 png files, 48 anno files, same size
# ./Validation/Rapiscan/SSD/Single_Default : 33 png files, 33 anno files, same size
# ./Validation/Rapiscan/SSD/Single_Other : 30 png files, 30 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/SupplymentaryBattery/Multiple_Categories : 152 png files, 152 anno files, same size
# ./Validation/Rapiscan/SupplymentaryBattery/Multiple_Other : 148 png files, 148 anno files, same size
# ./Validation/Rapiscan/SupplymentaryBattery/Single_Default : 568 png files, 568 anno files, same size
# ./Validation/Rapiscan/SupplymentaryBattery/Single_Other : 568 png files, 568 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/TabletPC/Multiple_Categories : 63 png files, 63 anno files, same size
# /content/drive/MyDrive/datasets/xray/Annotation/Validation/Rapiscan/TabletPC/Multiple_Other is not exist...
# ./Validation/Rapiscan/TabletPC/Single_Default : 38 png files, 38 anno files, same size
# ./Validation/Rapiscan/TabletPC/Single_Other : 45 png files, 45 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/Thinner/Multiple_Categories : 25 png files, 25 anno files, same size
# ./Validation/Rapiscan/Thinner/Multiple_Other : 30 png files, 30 anno files, same size
# ./Validation/Rapiscan/Thinner/Single_Default : 25 png files, 25 anno files, same size
# ./Validation/Rapiscan/Thinner/Single_Other : 25 png files, 25 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/ThrowingKnife/Multiple_Categories : 25 png files, 25 anno files, same size
# ./Validation/Rapiscan/ThrowingKnife/Multiple_Other : 30 png files, 30 anno files, same size
# ./Validation/Rapiscan/ThrowingKnife/Single_Default : 15 png files, 15 anno files, same size
# ./Validation/Rapiscan/ThrowingKnife/Single_Other : 15 png files, 15 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/USB/Multiple_Categories : 305 png files, 305 anno files, same size
# ./Validation/Rapiscan/USB/Multiple_Other : 94 png files, 94 anno files, same size
# ./Validation/Rapiscan/USB/Single_Default : 96 png files, 96 anno files, same size
# ./Validation/Rapiscan/USB/Single_Other : 95 png files, 95 anno files, same size
# ====================================================================================================
# ./Validation/Rapiscan/ZippoOil/Multiple_Categories : 25 png files, 25 anno files, same size
# ./Validation/Rapiscan/ZippoOil/Multiple_Other : 30 png files, 30 anno files, same size
# ./Validation/Rapiscan/ZippoOil/Single_Default : 15 png files, 15 anno files, same size
# ./Validation/Rapiscan/ZippoOil/Single_Other : 15 png files, 15 anno files, same size
# ====================================================================================================
# ====================================================================================================

# %% [markdown]
# ### 어노테이션보다 이미지가 더 많으면 어노테이션이 없는 이미지 삭제

# %% [markdown]
# #### 이상있는 디렉토리에만 접근함. 드라이브 시간초과 없음.

# %%
import os
import glob

del_file_dirs = [
                 "/Train/Smith/Bullet/Single_Other"
]

txt_path = "/content/drive/MyDrive/datasets/xray/del_files.txt"
with open(txt_path, "w") as f:
  for del_file_dir in del_file_dirs:
    png_path = f"/content/drive/MyDrive/datasets/xray/{del_file_dir}/*.png"
    anno_path = f"/content/drive/MyDrive/datasets/xray/Annotation/{del_file_dir}/*.txt"
    png_names = glob.glob(png_path)
    anno_names = glob.glob(anno_path)
    if len(png_names) > len(anno_names):
      for png in png_names:
        png2txt = png.replace("png", "txt").replace("xray", "xray/Annotation")
        if png2txt not in anno_names:
          print(png)
          os.system(f"rm {png}")
          f.write(png +'\n')
# Out:
# /content/drive/MyDrive/datasets/xray//Train/Smith/Bullet/Single_Other/H_9306.30-9000_04_314.png
# /content/drive/MyDrive/datasets/xray//Train/Smith/Bullet/Single_Other/H_9306.30-9000_04_566.png
# /content/drive/MyDrive/datasets/xray//Train/Smith/Bullet/Single_Other/H_9306.30-9000_05_323.png
# /content/drive/MyDrive/datasets/xray//Train/Smith/Bullet/Single_Other/H_9306.30-9000_05_575.png
# /content/drive/MyDrive/datasets/xray//Train/Smith/Bullet/Single_Other/H_9306.30-9000_06_314.png
# /content/drive/MyDrive/datasets/xray//Train/Smith/Bullet/Single_Other/H_9306.30-9000_06_566.png

# %% [markdown]
# #### Original : 드라이브 시간 초과 나옴

# %%
import os
import glob

modes = [
  "Train", 
  "Validation"
]
companies = [
  "Smith",
  "Astrophysics",
  "Rapiscan"
]
classes = [
  "Aerosol", "Alcohol", "Awl", "Axe", "Bat", "Battery", "Bullet", "Chisel", "ElectronicCigarettes",
  "ElectronicCigarettesLiquid", "Firecracker", "Gun", "GunParts", "Hammer", "HandCuffs",
  "HDDExternal", "HDD", "Knife", "LapTop", "Lighter", "Liquid", "Match", "MetalPipe", "NailClippers",
  "Plier", "PortableGas", "Saw", "Scissors", "Screwdriver", "SmartPhone", "SolidFuel", "Spanner",
  "SSD", "SupplymentaryBattery", "TabletPC", "Thinner", "ThrowingKnife", "USB", "ZippoOil"
]
categories = [
  "Multiple_Categories",
  "Multiple_Other",
  "Single_Default",
  "Single_Other"
]

txt_path = "/content/drive/MyDrive/datasets/xray/del_files.txt"
with open(txt_path, "w") as f:
  for m in modes:
    for com in companies:
      for cls in classes:
        for ctg in categories:
          png_path = f"/content/drive/MyDrive/datasets/xray/{m}/{com}/{cls}/{ctg}/*.png"
          anno_path = f"/content/drive/MyDrive/datasets/xray/Annotation/{m}/{com}/{cls}/{ctg}/*.txt"
          if os.path.exists(png_path) and os.path.exists(anno_path):
            png_names = glob.glob(png_path)
            anno_names = glob.glob(anno_path)
            if len(png_names) > len(anno_names):
              for png in png_names:
                png2txt = png.replace("png", "txt")
                if png2txt not in anno_names:
                  os.system(f"rm {png}")
                  f.write(png +'\n')
          else:
            if os.path.exists(png_path):
              print(png_path, "is not exist...")
            if os.path.exists(anno_path):
              print(anno_path, "is not exist...")

# %% [markdown]
# ## json annotation parser

# %%
import os
import xml.etree.ElementTree as elemTree
import glob
import shutil
import zipfile 

path = "/content/drive/MyDrive/datasets/xray/Annotation/Train.zip"
os.system(f"cp {path} /content")

unpack_zipfile = zipfile.ZipFile("/content/Train.zip")
unpack_zipfile.extractall("/content")
unpack_zipfile.close()

# %%
import json

companies = [
        "smith", 
        #"astrophysics", 
        #"rapiscan"
]
classes = ["Aerosol", "Alcohol", "Awl", "Axe", "Bat", "Battery", "Bullet", "Chisel", "ElectronicCigarettes",
        "ElectronicCigarettesLiquid", "Firecracker", "Gun", "GunParts", "Hammer", "HandCuffs",
        "HDDExternal", "HDD", "Knife", "LapTop", "Lighter", "Liquid", "Match", "MetalPipe", "NailClippers",
        "Plier", "PortableGas", "Saw", "Scissors", "Screwdriver", "SmartPhone", "SolidFuel", "Spanner",
        "SSD", "SupplymentaryBattery", "TabletPC", "Thinner", "ThrowingKnife", "USB", "ZippoOil"]
to_change = {
        "Electronic cigarettes":"ElectronicCigarettes", 
        "Electronic_cigarettes":"ElectronicCigarettes", 
        "Electronic cigarettes_Liquid":"ElectronicCigarettesLiquid", 
        "Electronic cigarettes(Liquid)":"ElectronicCigarettesLiquid", 
        "ElectronicCigarettes_Liquid":"ElectronicCigarettesLiquid",
        "HDD_External":"HDDExternal", 
        "Throwing Knife":"ThrowingKnife",
        "stun gun":"Gun",
        "PrtableGas":"PortableGas",
        "Laptop":"LapTop"
}
modes = ["Train"]

for company in companies:
  for m in modes:
    print(company)
    json_path = f"/content/{m}/CoCo/coco_{company}.json"

    with open(json_path, "r") as fj:
      json_file = json.load(fj)

    images = json_file["images"]
    categories = json_file["categories"]
    annotations = json_file["annotations"]

    for img, anno in zip(images, annotations):
      img_path = img["path"].split("\\")[-4:]
      img_path[-1] = img_path[-1].replace("png", "txt")
      if img_path[1] in to_change:
        img_path[1] = to_change[img_path[1]]
      cls = img_path[1]

      save_path = f"/content/drive/MyDrive/datasets/xray/Annotation/{m}/" + "/".join(img_path)
      print(save_path)

      img_w = img["width"]
      img_h = img["height"]

      try:
        with open(save_path, "w") as f:
          for i, seg in enumerate(anno["segmentation"]):
            cls_idx = classes.index(cls)

            x = seg[0::2]
            y = seg[1::2]

            xmax = max(x)
            xmin = min(x)
            ymax = max(y)
            ymin = min(y)

            x = (xmax + xmin / 2) / img_w
            y = (ymax + ymin / 2) / img_h
            w = (xmax - xmin) / img_w
            h = (ymax - ymin) / img_h

            save_string = f"{cls_idx} {x} {y} {w} {h}"
            
            f.write(save_string)

      except FileNotFoundError:
        print("Some error occurred!")
        error_file_path = "/content/drive/MyDrive/datasets/xray/error.txt"
        with open(error_file_path, "a") as f:
          f.write(save_path + "\n")
          line = "=="*50
          f.write("line" + "\n")
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Default/S_8523.51-1000_01_255.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Default/S_8523.51-1000_01_256.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Default/S_8523.51-1000_01_257.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Default/S_8523.51-1000_01_258.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Default/S_8523.51-1000_01_259.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Default/S_8523.51-1000_01_260.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Default/S_8523.51-1000_01_261.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Default/S_8523.51-1000_01_262.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Default/S_8523.51-1000_01_263.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Default/S_8523.51-1000_01_264.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Default/S_8523.51-1000_01_265.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Default/S_8523.51-1000_01_266.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Default/S_8523.51-1000_01_267.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Default/S_8523.51-1000_01_268.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Default/S_8523.51-1000_01_269.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Default/S_8523.51-1000_01_270.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Default/S_8523.51-1000_01_271.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Default/S_8523.51-1000_01_272.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Default/S_8523.51-1000_01_273.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Default/S_8523.51-1000_01_274.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other/S_8523.51-1000_01_280.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other/S_8523.51-1000_01_281.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other/S_8523.51-1000_01_282.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other/S_8523.51-1000_01_283.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other/S_8523.51-1000_01_284.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other/S_8523.51-1000_01_285.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other/S_8523.51-1000_01_286.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other/S_8523.51-1000_01_287.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other/S_8523.51-1000_01_288.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other/S_8523.51-1000_01_289.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other/S_8523.51-1000_01_290.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other/S_8523.51-1000_01_291.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other/S_8523.51-1000_01_292.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other/S_8523.51-1000_01_293.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other/S_8523.51-1000_01_294.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other/S_8523.51-1000_01_295.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other/S_8523.51-1000_01_296.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other/S_8523.51-1000_01_297.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other/S_8523.51-1000_01_298.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other/S_8523.51-1000_01_299.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other/S_8523.51-1000_01_300.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other/S_8523.51-1000_01_301.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other/S_8523.51-1000_01_302.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other/S_8523.51-1000_01_303.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Other/S_8523.51-1000_01_304.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Multiple_Other/S_8523.51-1000_01_310.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith
txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/USB/Multiple_Categories/S_8544.42-2090_20_487.txt

# %% [markdown]
# ### test

# %%
import json

json_path = f"/content/drive/MyDrive/datasets/xray/Annotation/Train/CoCo/coco_smith.json"

with open(json_path, "r") as fj:
  json_file = json.load(fj)

print(json_file["images"][0])
print(json_file["annotations"][0])

# %% [markdown]
# ## xml annotation parser

# %% [markdown]
# ### deleter

# %%
import os
import glob

modes = [
  "Train", 
  "Validation"
]
companies = [
  "Smith",
  "Astrophysics",
  "Rapiscan"
]
classes = [
  "Aerosol", "Alcohol", "Awl", "Axe", "Bat", "Battery", "Bullet", "Chisel", "ElectronicCigarettes",
  "ElectronicCigarettesLiquid", "Firecracker", "Gun", "GunParts", "Hammer", "HandCuffs",
  "HDDExternal", "HDD", "Knife", "LapTop", "Lighter", "Liquid", "Match", "MetalPipe", "NailClippers",
  "Plier", "PortableGas", "Saw", "Scissors", "Screwdriver", "SmartPhone", "SolidFuel", "Spanner",
  "SSD", "SupplymentaryBattery", "TabletPC", "Thinner", "ThrowingKnife", "USB", "ZippoOil"
]
categories = [
  "Multiple_Categories",
  "Multiple_Other",
  "Single_Default",
  "Single_Other"
]

for m in modes:
  for com in companies:
    for cls in classes:
      for ctg in categories:
        path = f"/content/drive/MyDrive/datasets/xray/Annotation/{m}/{com}/{cls}/{ctg}"
        if os.path.exists(path):
          txt_list = glob.glob(f"{path}/*.txt")
          for txt in txt_list:
            os.system(f"rm {txt}")
        else:
          print(path, "is not exist...")

for m in modes:
  for com in companies:
    for cls in classes:
      for ctg in categories:
        path = f"/content/drive/MyDrive/datasets/xray/Annotation/{m}/Origin/Pascal/{com}"
        if os.path.exists(path):
          xml_list = glob.glob(f"{path}/*.xml")
          dest_path = f"/content/drive/MyDrive/datasets/xray/Annotation/{m}/Pascal/{com}"
          for xml in xml_list:
            os.system(f"mv {xml} {dest_path}")
        else:
          print(path, "is not exist...")

# %% [markdown]
# ### xml parser

# %%
import os
import xml.etree.ElementTree as elemTree
import glob
import shutil
import zipfile 

path = "/content/drive/MyDrive/datasets/xray/Annotation/Train.zip"
os.system(f"cp {path} /content")

unpack_zipfile = zipfile.ZipFile("/content/Train.zip")
unpack_zipfile.extractall("/content")
unpack_zipfile.close()

# %%
classes = ["Aerosol", "Alcohol", "Awl", "Axe", "Bat", "Battery", "Bullet", "Chisel", "ElectronicCigarettes",
        "ElectronicCigarettesLiquid", "Firecracker", "Gun", "GunParts", "Hammer", "HandCuffs",
        "HDDExternal", "HDD", "Knife", "LapTop", "Lighter", "Liquid", "Match", "MetalPipe", "NailClippers",
        "Plier", "PortableGas", "Saw", "Scissors", "Screwdriver", "SmartPhone", "SolidFuel", "Spanner",
        "SSD", "SupplymentaryBattery", "TabletPC", "Thinner", "ThrowingKnife", "USB", "ZippoOil"]
to_change = {"Electronic cigarettes":"ElectronicCigarettes", 
             "Electronic_cigarettes":"ElectronicCigarettes", 
             "Electronic cigarettes_Liquid":"ElectronicCigarettesLiquid", 
             "Electronic cigarettes(Liquid)":"ElectronicCigarettesLiquid", 
             "ElectronicCigarettes_Liquid":"ElectronicCigarettesLiquid",
             "HDD_External":"HDDExternal", 
             "Throwing Knife":"ThrowingKnife",
             "stun gun":"Gun",
             "PrtableGas":"PortableGas",
             "Laptop":"LapTop"
}
modes = ["Train"]
companies = [
             "Smith"
]

for mode in modes:
  print("="*50)
  root_path = f"/content/drive/MyDrive/datasets/xray/Annotation/{mode}"

  for com in companies:
    xml_dir = f"/content/Train/Pascal/{com}/*.xml"
    print(xml_dir)
    xml_path_list = glob.glob(xml_dir, recursive=True)    

    for xml_path in xml_path_list:
      if "xml" not in xml_path: continue
      tree = elemTree.parse(xml_path)
      root = tree.getroot()
      
      size = root.find("size")      
      img_w = int(size.findtext("width"))
      img_h = int(size.findtext("height"))

      anno_path = root.find("path").text.split("\\")[-4:]
      if anno_path[1] in to_change:
        anno_path[1] = to_change[anno_path[1]]
      anno_path[-1] = anno_path[-1].replace("png", "txt")
      anno_path = '/'.join(anno_path)
      save_path = f"{root_path}/{anno_path}"
      print(save_path)

      try:
        with open(save_path, "w") as f:
          for obj in root.iter("object"):
            cls = obj.find("name").text
            if cls in to_change:
              cls = to_change[cls]
            cls_idx = classes.index(cls)

            xmin = int(obj.find("bndbox").findtext("xmin"))
            xmax = int(obj.find("bndbox").findtext("xmax"))
            ymin = int(obj.find("bndbox").findtext("ymin"))
            ymax = int(obj.find("bndbox").findtext("ymax"))

            x = (xmax + xmin / 2) / img_w
            y = (ymax + ymin / 2) / img_h
            w = (xmax - xmin) / img_w
            h = (ymax - ymin) / img_h

            save_str = f"{cls_idx} {x} {y} {w} {h}\n"
            f.write(save_str)

      except FileNotFoundError:
        print(f"Some error occurred : {save_path}")
        error_file_path = "/content/drive/MyDrive/datasets/xray/error.txt"
        with open(error_file_path, "a") as f:
          f.write(xml_path + "\n")
          f.write(save_path + "\n")
          line = "=="*50
          f.write(f"{line}" + "\n")

print("Done!")
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SolidFuel/Multiple_Categories/H_7321.89-0000_02_310.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/NailClippers/Multiple_Other/H_8214.20-0000_05_319.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/PortableGas/Multiple_Categories/H_7321.11-0000_01_398.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Chisel/Multiple_Categories/H_8205.30-0000_17_404.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Awl/Multiple_Categories/H_8207.50-1090_16_102.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/TabletPC/Single_Default/S_8471.30-0000_22_128.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Screwdriver/Multiple_Categories/H_8205.40-0000_21_310.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SupplymentaryBattery/Single_Other/H_8507.60-1000_10_132.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Liquid/Multiple_Categories/H_93307.90-9000_04_420.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Knife/Multiple_Other/H_8211.91-0000_21_273.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Scissors/Single_Default/H_8213.00-1000_06_133.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/ThrowingKnife/Multiple_Categories/H_8211.92-0000_02_229.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Scissors/Multiple_Categories/H_8213.00-1000_12_545.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/HandCuffs/Single_Default/H_7326.90-9000_04_348.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Firecracker/Multiple_Other/H_9405.40-9000_23_374.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SSD/Single_Default/S_8523.51-1000_02_281.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/SmartPhone/Multiple_Other/S_8517.70-1029_05_247.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/TabletPC/Multiple_Other/S_8471.30-0000_26_203.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Chisel/Multiple_Categories/H_8205.30-0000_17_299.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Knife/Multiple_Categories/H_8211.91-0000_08_090.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/GunParts/Multiple_Categories/H_8424.90-2000_12_444.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/MetalPipe/Single_Other/H_7306.90-9000_11_365.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Saw/Multiple_Categories/H_8202.39-2090_07_471.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith
txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Hammer/Multiple_Categories/H_8205.20-0000_04_610.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Aerosol/Multiple_Categories/H_8481.80-1090_03_438.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Knife/Single_Default/H_8211.91-0000_15_420.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Chisel/Multiple_Categories/H_8205.30-0000_06_421.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Saw/Multiple_Categories/H_8202.39-2090_10_477.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Plier/Multiple_Other/H_8203.20-1000_09_330.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Gun/Single_Default/H_8424.20-1000_19_292.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/ElectronicCigarettes/Multiple_Other/H_8543.70-4000_03_334.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Plier/Single_Other/H_8203.20-1000_17_367.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/ZippoOil/Multiple_Categories/H_2707.99-1000_03_286.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Chisel/Multiple_Other/H_8205.30-0000_23_445.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Saw/Multiple_Categories/H_8202.39-2090_28_374.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Hammer/Multiple_Categories/H_8205.20-0000_08_626.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Saw/Multiple_Other/H_8202.39-2090_08_404.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Gun/Multiple_Categories/H_8424.20-1000_20_411.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Chisel/Multiple_Categories/H_8205.30-0000_18_284.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Lighter/Multiple_Categories/H_9613.80-0000_12_477.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/GunParts/Single_Default/H_8424.90-2000_05_310.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Spanner/Multiple_Categories/H_8204.20-0000_02_301.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/TabletPC/Multiple_Categories/S_8471.30-0000_21_242.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Awl/Multiple_Categories/H_8207.50-1090_04_080.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Lighter/Multiple_Categories/H_9613.80-0000_20_378.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Awl/Single_Default/H_8207.50-1090_02_020.txt
# /content/drive/MyDrive/datasets/xray/Annotation/Train/Smith/Knife/Multiple_Other/H_8211.91-0000_22_282.txt
# Done!

# %% [markdown]
# ## txt maker

# %%
import glob 

t_smith = "/content/drive/MyDrive/datasets/xray/Train/Smith/**"
t_rapiscan = "/content/drive/MyDrive/datasets/xray/Train/Rapiscan/**"
t_astrophysics = "/content/drive/MyDrive/datasets/xray/Train/Astrophysics/**"

v_smith = "/content/drive/MyDrive/datasets/xray/Validation/Smith/**"
v_rapiscan = "/content/drive/MyDrive/datasets/xray/Validation/Rapiscan/**"
v_astrophysics = "/content/drive/MyDrive/datasets/xray/Validation/Astrophysics/**"

t_smith_list = glob.glob(t_smith, recursive=True)
t_rapiscan_list = glob.glob(t_rapiscan, recursive=True)
t_astrophysics_list = glob.glob(t_astrophysics, recursive=True)
t_all_list = t_smith_list + t_rapiscan_list + t_astrophysics_list

v_smith_list = glob.glob(v_smith, recursive=True)
v_rapiscan_list = glob.glob(v_rapiscan, recursive=True)
v_astrophysics_list = glob.glob(v_astrophysics, recursive=True)
v_all_list = v_smith_list + v_rapiscan_list + v_astrophysics_list

dir_dict = {
  "train_smith":t_smith_list, 
  "train_rapiscan":t_rapiscan_list, 
  "train_astrophysics":t_astrophysics_list, 
  "train_all":t_all_list, 
  "valid_smith":v_smith_list, 
  "valid_rapiscan":v_rapiscan_list, 
  "valid_astrophysics":v_astrophysics_list, 
  "valid_all":v_all_list
}

# %%
txt_dir = "/content/drive/MyDrive/yolor/data"
for name, dirs in dir_dict.items():
  txt_path = f"{txt_dir}/{name}.txt"
  with open(txt_path, "w") as f:
    for data in dirs:
      if "png" in data:
        f.write(data + "\n")
    print(txt_path)
# Out:
# /content/drive/MyDrive/yolor/data/train_smith.txt
# /content/drive/MyDrive/yolor/data/train_rapiscan.txt
# /content/drive/MyDrive/yolor/data/train_astrophysics.txt
# /content/drive/MyDrive/yolor/data/train_all.txt
# /content/drive/MyDrive/yolor/data/valid_smith.txt
# /content/drive/MyDrive/yolor/data/valid_rapiscan.txt
# /content/drive/MyDrive/yolor/data/valid_astrophysics.txt
# /content/drive/MyDrive/yolor/data/valid_all.txt

# %% [markdown]
# ## bbox 잘 쳐지는지 확인함

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw

classes = [
  "Aerosol", "Alcohol", "Awl", "Axe", "Bat", "Battery", "Bullet", "Chisel", "ElectronicCigarettes",
  "ElectronicCigarettesLiquid", "Firecracker", "Gun", "GunParts", "Hammer", "HandCuffs",
  "HDDExternal", "HDD", "Knife", "LapTop", "Lighter", "Liquid", "Match", "MetalPipe", "NailClippers",
  "Plier", "PortableGas", "Saw", "Scissors", "Screwdriver", "SmartPhone", "SolidFuel", "Spanner",
  "SSD", "SupplymentaryBattery", "TabletPC", "Thinner", "ThrowingKnife", "USB", "ZippoOil"
]
imgsz = [1680, 1050]
sample_path = ""
sample_img_path = f"/content/drive/MyDrive/datasets/xray/Train/{sample_path}"
sample_anno_path = sample_img_path.replace("Train", "Annotation/Train").replace("png", "txt")

img = Image.open(sample_img_path).convert("RGB")
draw = ImageDraw.Draw(img)

with open(sample_anno_path, "r") as f:
  lines = f.readlines()
  for line in lines:
    data = line.strip().split(" ")
    
    cls = classes[int(data[0])]
    x = float(data[1])*imgsz[0]
    y = float(data[2])*imgsz[1]
    w = float(data[3])*imgsz[0]
    h = float(data[4])*imgsz[1]

    x1 = x - w / 2
    y1 = h - w / 2
    x2 = x + w / 2
    y2 = h + w / 2

    draw.text((x1, y1-10), cls, fill = "red")
    draw.rectangle((x1, y1, x2, y2), outline="red")


plt.imshow(np.array(img))
plt.show()

# %% [markdown]
# # Train Model

# %% [markdown]
# ## 파일 준비 및 학습 준비

# %%
from distutils.dir_util import copy_tree
copy_tree("/content/drive/MyDrive/yolor", "/content")

# %%
# !pip install -U PyYAML

# %% [markdown]
# ## train command

# %% [markdown]
# ### 처음 학습시 사용

# %%
COMPANY = "Smith"

# %%
# !python train.py --batch-size 8 --img 1960 1960 --data /content/data/coco_{COMPANY}.yaml --cfg /content/cfg/yolor_p6.cfg --weights '' --device 0 --name yolor_{COMPANY} --hyp /content/data/hyp.scratch.1280.yaml --epochs 300 --adam --project /content/drive/MyDrive/yolor/runs/train

# %% [markdown]
# ### 이어서 학습시 사용

# %%
COMPANY = "Smith"

# %%
# !python train.py --batch-size 8 --img 1960 1960 --data /content/data/coco_{COMPANY}.yaml --cfg /content/cfg/yolor_p6.cfg --weights '' --device 0 --name yolor_{COMPANY} --hyp /content/data/hyp.scratch.1280.yaml --epochs 300 --adam --project /content/drive/MyDrive/yolor/runs/train --resume

# %% [markdown]
# ## tensor board

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir {'/content/drive/MyDrive/tb_logs/train'}
